# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../../Data/School/0001/school.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  school_id  male_graduates  male_high_school  \
# 0           0        101             172                43
# 1           1        102             141                64
# 2           2        103             300               218
# 3           3        104             219               115
# 4           4        105             220                67
#
#    male_part_time_high_school  male_employed  male_home_and_high_school  \
# 0                          18             91                          4
# 1                           6             62                          2
# 2                           8             56                          0
# 3                          18             80                          1
# 4                          18            133                          0
#
#    male_home  male_others  female_graduates  female_high_school  \
# 0         13            3               157                  58
# ...

# %%
df['school_id'].unique()
# Out:
# array([ 101,  102,  103,  104,  105,  111,  112,  113,  114,  115,  116,
#         201,  202,  203,  204,  205,  206,  211,  212,  213,  214,  221,
#         222,  223,  231,  232,  233,  241,  242,  243,  244,  245,  251,
#         252,  261,  262,  263,  271,  272,  281,  282,  283,  301,  302,
#         303,  304,  305,  306,  311,  312,  321,  322,  323,  324,  325,
#         326,  327,  331,  332,  333,  334,  335,  336,  337,  401,  402,
#         403,  404,  405,  406,  407,  501,  502,  503,  504,  511,  512,
#         513,  601,  602,  603,  604,  605,  606,  611,  612,  613,  701,
#         702,  703,  704,  705,  711,  712,  713,  721,  722,  723,  724,
#         801,  802,  803,  804,  805,  806,  807,  808,  809,  810,  811,
#         812,  813,  814,  815,  816,  901,  902,  903,  904,  905,  906,
#         907,  908,  909,  910,  911,  912,  913,  914,  915,  916,  917,
#         918,  919, 1001, 1002, 1003, 1004, 1005, 1011, 1012, 1013, 1014,
# ...

# %%
total_graduates=df['male_graduates']+df['female_graduates']

# %%
total_graduates
# Out:
# 0      329
# 1      272
# 2      517
# 3      387
# 4      452
#       ...
# 183    102
# 184     60
# 185     41
# 186     62
# 187     48
# Length: 188, dtype: int64

# %%
df['total_graduates']=total_graduates

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'school_id', 'male_graduates', 'male_high_school',
#        'male_part_time_high_school', 'male_employed',
#        'male_home_and_high_school', 'male_home', 'male_others',
#        'female_graduates', 'female_high_school',
#        'female_part_time_high_school', 'female_employed',
#        'female_home_and_high_school', 'female_home', 'female_others',
#        'total_graduates'],
#       dtype='object')

# %%
df['total_graduates'].describe()
# Out:
# count     188.000000
# mean      235.792553
# std       230.867938
# min        15.000000
# 25%       113.000000
# 50%       174.500000
# 75%       313.750000
# max      1998.000000
# Name: total_graduates, dtype: float64

# %%
df['total_graduates'][df.total_graduates>=1000]
# Out:
# 61     1998
# 177    1998
# Name: total_graduates, dtype: int64

# %%
df[61:]
# Out:
#      Unnamed: 0  school_id  male_graduates  male_high_school  \
# 61           61        335             999               999
# 62           62        336              83                24
# 63           63        337              30                10
# 64           64        401             292               145
# 65           65        402             301               161
# ..          ...        ...             ...               ...
# 183         183       1308              52                30
# 184         184       1309              29                13
# 185         185       1310              27                 6
# 186         186       1311              32                 3
# 187         187       1312              23                 8
#
#      male_part_time_high_school  male_employed  male_home_and_high_school  \
# 61                           99            999                         99
# 62                            8             18                          1
# ...

# %%
df[df.male_graduates==999]
# Out:
#      Unnamed: 0  school_id  male_graduates  male_high_school  \
# 61           61        335             999               999
# 177         177       1302             999               999
#
#      male_part_time_high_school  male_employed  male_home_and_high_school  \
# 61                           99            999                         99
# 177                          99            999                         99
#
#      male_home  male_others  female_graduates  female_high_school  \
# 61          99           99               999                 999
# 177         99           99               999                 999
#
#      female_part_time_high_school  female_employed  \
# 61                             99              999
# 177                            99              999
#
#      female_home_and_high_school  female_home  female_others  total_graduates
# 61                            99           99             99             1998
# ...

# %%
df[df.female_graduates==999]
# Out:
#      Unnamed: 0  school_id  male_graduates  male_high_school  \
# 61           61        335             999               999
# 177         177       1302             999               999
#
#      male_part_time_high_school  male_employed  male_home_and_high_school  \
# 61                           99            999                         99
# 177                          99            999                         99
#
#      male_home  male_others  female_graduates  female_high_school  \
# 61          99           99               999                 999
# 177         99           99               999                 999
#
#      female_part_time_high_school  female_employed  \
# 61                             99              999
# 177                            99              999
#
#      female_home_and_high_school  female_home  female_others  total_graduates
# 61                            99           99             99             1998
# ...

# %%
no_reply_schools = df.male_graduates == 999

# %%
no_reply_schools
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 183    False
# 184    False
# 185    False
# 186    False
# 187    False
# Name: male_graduates, Length: 188, dtype: bool

# %%
df_updated = df[df.male_graduates!=999]

# %%
df_updated.describe()
# Out:
#        Unnamed: 0    school_id  male_graduates  male_high_school  \
# count  186.000000   186.000000      186.000000        186.000000
# mean    93.225806   678.994624      113.059140         53.924731
# std     54.309649   377.892770       76.481842         47.424076
# min      0.000000   101.000000        4.000000          2.000000
# 25%     46.250000   305.250000       55.250000         18.000000
# 50%     93.500000   712.500000       87.000000         34.000000
# 75%    139.750000  1011.750000      157.000000         77.000000
# max    187.000000  1312.000000      349.000000        225.000000
#
#        male_part_time_high_school  male_employed  male_home_and_high_school  \
# count                  186.000000     186.000000                 186.000000
# mean                    15.543011      33.150538                  12.397849
# std                     27.494487      27.427130                  27.780857
# ...

# %%
df[df.male_part_time_high_school==99]
# Out:
#      Unnamed: 0  school_id  male_graduates  male_high_school  \
# 54           54        325              51                12
# 61           61        335             999               999
# 79           79        602              60                34
# 80           80        603             157               126
# 101         101        803              61                14
# 110         110        812              67                24
# 111         111        813              59                22
# 123         123        909              56                17
# 125         125        911              61                22
# 146         146       1018              15                 8
# 151         151       1101              33                 6
# 157         157       1107               4                 2
# 158         158       1108              29                20
# 160         160       1110              32                21
# ...

# %%
df[df.male_home_and_high_school==99]
# Out:
#      Unnamed: 0  school_id  male_graduates  male_high_school  \
# 9             9        115             187                90
# 35           35        262             210               136
# 54           54        325              51                12
# 61           61        335             999               999
# 73           73        503              54                14
# 79           79        602              60                34
# 80           80        603             157               126
# 143         143       1015              26                17
# 144         144       1016              33                20
# 146         146       1018              15                 8
# 150         150       1022              87                44
# 157         157       1107               4                 2
# 158         158       1108              29                20
# 160         160       1110              32                21
# ...

# %%
df[df.male_home==99]
# Out:
#      Unnamed: 0  school_id  male_graduates  male_high_school  \
# 61           61        335             999               999
# 157         157       1107               4                 2
# 177         177       1302             999               999
#
#      male_part_time_high_school  male_employed  male_home_and_high_school  \
# 61                           99            999                         99
# 157                          99              2                         99
# 177                          99            999                         99
#
#      male_home  male_others  female_graduates  female_high_school  \
# 61          99           99               999                 999
# 157         99           99                11                   3
# 177         99           99               999                 999
#
#      female_part_time_high_school  female_employed  \
# 61                             99              999
# ...

# %%
df[df.female_others==99]
# Out:
#      Unnamed: 0  school_id  male_graduates  male_high_school  \
# 3             3        104             219               115
# 4             4        105             220                67
# 9             9        115             187                90
# 11           11        201             281               134
# 14           14        204             152                74
# ..          ...        ...             ...               ...
# 171         171       1208              56                19
# 173         173       1210              22                 8
# 174         174       1211              44                13
# 177         177       1302             999               999
# 179         179       1304              22                 8
#
#      male_part_time_high_school  male_employed  male_home_and_high_school  \
# 3                            18             80                          1
# 4                            18            133                          0
# ...

# %%
df[df.female_home==99]
# Out:
#      Unnamed: 0  school_id  male_graduates  male_high_school  \
# 61           61        335             999               999
# 138         138       1005              42                29
# 145         145       1017              24                12
# 160         160       1110              32                21
# 177         177       1302             999               999
#
#      male_part_time_high_school  male_employed  male_home_and_high_school  \
# 61                           99            999                         99
# 138                           2              8                          2
# 145                           4              4                          2
# 160                          99              5                         99
# 177                          99            999                         99
#
#      male_home  male_others  female_graduates  female_high_school  \
# 61          99           99               999                 999
# ...

# %%
df[df.male_home==99]
# Out:
#      Unnamed: 0  school_id  male_graduates  male_high_school  \
# 61           61        335             999               999
# 157         157       1107               4                 2
# 177         177       1302             999               999
#
#      male_part_time_high_school  male_employed  male_home_and_high_school  \
# 61                           99            999                         99
# 157                          99              2                         99
# 177                          99            999                         99
#
#      male_home  male_others  female_graduates  female_high_school  \
# 61          99           99               999                 999
# 157         99           99                11                   3
# 177         99           99               999                 999
#
#      female_part_time_high_school  female_employed  \
# 61                             99              999
# ...

# %%
df[df.male_employed==999]
# Out:
#      Unnamed: 0  school_id  male_graduates  male_high_school  \
# 61           61        335             999               999
# 177         177       1302             999               999
#
#      male_part_time_high_school  male_employed  male_home_and_high_school  \
# 61                           99            999                         99
# 177                          99            999                         99
#
#      male_home  male_others  female_graduates  female_high_school  \
# 61          99           99               999                 999
# 177         99           99               999                 999
#
#      female_part_time_high_school  female_employed  \
# 61                             99              999
# 177                            99              999
#
#      female_home_and_high_school  female_home  female_others  total_graduates
# 61                            99           99             99             1998
# ...

# %%
id = ['male_graduates', 'male_high_school']
df[id[0]]
# Out:
# 0      172
# 1      141
# 2      300
# 3      219
# 4      220
#       ...
# 183     52
# 184     29
# 185     27
# 186     32
# 187     23
# Name: male_graduates, Length: 188, dtype: int64

# %%
gender = ['male','female']
attribute = ['_graduates','_high_school']
id = []
for i in range(2):
    for j in range(2):
        id.append(gender[i] +attribute[j])

# %%
id
# Out:
# ['male_graduates',
#  'male_high_school',
#  'female_graduates',
#  'female_high_school']

# %%
a = gender[0]+attribute[1]

# %%
a
# Out:
# 'male_high_school'

# %%
df[df.male_home==99].male_employed+ df[df.male_home==99].male_high_school
# Out:
# 61     1998
# 157       4
# 177    1998
# dtype: int64

# %%
df[df.male_home==99].male_graduates
# Out:
# 61     999
# 157      4
# 177    999
# Name: male_graduates, dtype: int64

# %%
index_home_null= df[df.male_home == 99].index

# %%
for i in index_home_null:
    if df.iloc[i].male_graduates == (df.iloc[i].male_employed+ df.iloc[i].male_high_school):
        df.iloc[i].male_home = 0
        df.iloc[i].male_part_time_high_school = 0
        df.iloc[i].male_home_and_high_school =0
        df.iloc[i].male_others=0

# %%
gender = ['male', 'female']
#index = vars()["index_home_null_" + gender[1]]
index = df[df.loc[:,gender[1]+'_home']==99].index
index
# Out:
# Int64Index([61, 138, 145, 160, 177], dtype='int64')

# %%
df.iloc[index[1]].loc[gender[1]+'_graduates']
# Out:
# 54

# %%
for i in index:
    if df.iloc[i].loc[gender[1]+'_graduates'] == (df.iloc[i].loc[gender[1]+'_high_school'] +df.iloc[i].loc[gender[1]+'_employed']):
        df.iloc[i].loc[gender[1]+'_home'] = 0
        df.iloc[i].loc[gender[1]+'_part_time_high_school'] = 0
        df.iloc[i].loc[gender[1]+'_home_and_high_school'] =0
        df.iloc[i].loc[gender[1]+'_others']=0

# %% [markdown]
# ## df.iloc[index]

# %%
df[df.female_part_time_high_school==99]
# Out:
#      Unnamed: 0  school_id  male_graduates  male_high_school  \
# 41           41        283              65                12
# 51           51        322              57                14
# 54           54        325              51                12
# 61           61        335             999               999
# 79           79        602              60                34
# 80           80        603             157               126
# 86           86        613              74                27
# 87           87        701             327               215
# 101         101        803              61                14
# 102         102        804              72                31
# 110         110        812              67                24
# 114         114        816              78                28
# 123         123        909              56                17
# 125         125        911              61                22
# ...

# %%
index_home_null_female
# Out:
#      Unnamed: 0  school_id  male_graduates  male_high_school  \
# 61           61        335             999               999
# 138         138       1005              42                29
# 145         145       1017              24                12
# 160         160       1110              32                21
# 177         177       1302             999               999
#
#      male_part_time_high_school  male_employed  male_home_and_high_school  \
# 61                           99            999                         99
# 138                           2              8                          2
# 145                           4              4                          2
# 160                          99              5                         99
# 177                          99            999                         99
#
#      male_home  male_others  female_graduates  female_high_school  \
# 61          99           99               999                 999
# ...

# %%
df.loc[:,gender[1]+'_home']
# Out:
# 0      25
# 1      25
# 2      13
# 3       8
# 4      17
#        ..
# 183    14
# 184     7
# 185     2
# 186    12
# 187     7
# Name: female_home, Length: 188, dtype: int64

# %%
df[df.female_home == 99]
# Out:
#      Unnamed: 0  school_id  male_graduates  male_high_school  \
# 61           61        335             999               999
# 138         138       1005              42                29
# 145         145       1017              24                12
# 160         160       1110              32                21
# 177         177       1302             999               999
#
#      male_part_time_high_school  male_employed  male_home_and_high_school  \
# 61                           99            999                         99
# 138                           2              8                          2
# 145                           4              4                          2
# 160                          99              5                         99
# 177                          99            999                         99
#
#      male_home  male_others  female_graduates  female_high_school  \
# 61          99           99               999                 999
# ...

# %%
df.iloc[157]
# Out:
# Unnamed: 0                       157
# school_id                       1107
# male_graduates                     4
# male_high_school                   2
# male_part_time_high_school         0
# male_employed                      2
# male_home_and_high_school          0
# male_home                          0
# male_others                        0
# female_graduates                  11
# female_high_school                 3
# female_part_time_high_school      99
# female_employed                    5
# female_home_and_high_school       99
# female_home                        3
# female_others                     99
# total_graduates                   15
# Name: 157, dtype: int64

# %%
bad_index[1]
# Out:
# 157

# %%
df.iloc[1,:].male_graduates
# Out:
# 141

# %%
df.iloc[bad_index[0]].male_graduates
# Out:
# 999

# %%
df.iloc[1]
# Out:
# Unnamed: 0                        1
# school_id                       102
# male_graduates                  141
# male_high_school                 64
# male_part_time_high_school        6
# male_employed                    62
# male_home_and_high_school         2
# male_home                         7
# male_others                       0
# female_graduates                131
# female_high_school               37
# female_part_time_high_school      2
# female_employed                  66
# female_home_and_high_school       1
# female_home                      25
# female_others                     0
# total_graduates                 272
# Name: 1, dtype: int64

# %%
df2 = pd.read_csv('../../Data/School/0001/school.csv')

# %%
df2.head()
# Out:
#    school_id  male_graduates  male_high_school  male_part_time_high_school  \
# 0        101             172                43                          18
# 1        102             141                64                           6
# 2        103             300               218                           8
# 3        104             219               115                          18
# 4        105             220                67                          18
#
#    male_employed  male_home_and_high_school  male_home  male_others  \
# 0             91                          4         13            3
# 1             62                          2          7            0
# 2             56                          0         18            0
# 3             80                          1          4            1
# 4            133                          0          2           99
#
#    female_graduates  female_high_school  female_part_time_high_school  \
# ...

# %%
df2.describe()
# Out:
#          school_id  male_graduates  male_high_school  \
# count   188.000000      188.000000        188.000000
# mean    680.478723      122.484043         63.978723
# std     379.449354      118.710427        108.055341
# min     101.000000        4.000000          2.000000
# 25%     305.750000       55.750000         18.000000
# 50%     712.500000       88.000000         34.500000
# 75%    1012.250000      159.000000         79.750000
# max    1312.000000      999.000000        999.000000
#
#        male_part_time_high_school  male_employed  male_home_and_high_school  \
# count                  188.000000     188.000000                 188.000000
# mean                    16.430851      43.425532                  13.319149
# std                     28.662904     103.030237                  29.032423
# min                      0.000000       1.000000                   0.000000
# 25%                      2.000000      14.000000                   1.000000
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 15 columns):
# school_id                       188 non-null int64
# male_graduates                  188 non-null int64
# male_high_school                188 non-null int64
# male_part_time_high_school      188 non-null int64
# male_employed                   188 non-null int64
# male_home_and_high_school       188 non-null int64
# male_home                       188 non-null int64
# male_others                     188 non-null int64
# female_graduates                188 non-null int64
# female_high_school              188 non-null int64
# female_part_time_high_school    188 non-null int64
# female_employed                 188 non-null int64
# female_home_and_high_school     188 non-null int64
# female_home                     188 non-null int64
# female_others                   188 non-null int64
# dtypes: int64(15)
# memory usage: 22.2 KB

# %%
df2[df2.male_graduates == 999]
# Out:
#      school_id  male_graduates  male_high_school  male_part_time_high_school  \
# 61         335             999               999                          99
# 177       1302             999               999                          99
#
#      male_employed  male_home_and_high_school  male_home  male_others  \
# 61             999                         99         99           99
# 177            999                         99         99           99
#
#      female_graduates  female_high_school  female_part_time_high_school  \
# 61                999                 999                            99
# 177               999                 999                            99
#
#      female_employed  female_home_and_high_school  female_home  female_others
# 61               999                           99           99             99
# 177              999                           99           99             99

# %%
df2.iloc[61]
# Out:
# school_id                       335
# male_graduates                  999
# male_high_school                999
# male_part_time_high_school       99
# male_employed                   999
# male_home_and_high_school        99
# male_home                        99
# male_others                      99
# female_graduates                999
# female_high_school              999
# female_part_time_high_school     99
# female_employed                 999
# female_home_and_high_school      99
# female_home                      99
# female_others                    99
# Name: 61, dtype: int64

# %%
df2 = df2[df2.male_graduates != 999]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186 entries, 0 to 187
# Data columns (total 15 columns):
# school_id                       186 non-null int64
# male_graduates                  186 non-null int64
# male_high_school                186 non-null int64
# male_part_time_high_school      186 non-null int64
# male_employed                   186 non-null int64
# male_home_and_high_school       186 non-null int64
# male_home                       186 non-null int64
# male_others                     186 non-null int64
# female_graduates                186 non-null int64
# female_high_school              186 non-null int64
# female_part_time_high_school    186 non-null int64
# female_employed                 186 non-null int64
# female_home_and_high_school     186 non-null int64
# female_home                     186 non-null int64
# female_others                   186 non-null int64
# dtypes: int64(15)
# memory usage: 23.2 KB

# %%
df2.iloc[185]
# Out:
# school_id                       1312
# male_graduates                    23
# male_high_school                   8
# male_part_time_high_school         0
# male_employed                      7
# male_home_and_high_school          2
# male_home                          5
# male_others                        1
# female_graduates                  25
# female_high_school                 6
# female_part_time_high_school       0
# female_employed                   11
# female_home_and_high_school        0
# female_home                        7
# female_others                      1
# Name: 187, dtype: int64

# %%
df2.describe()
# Out:
#          school_id  male_graduates  male_high_school  \
# count   186.000000      186.000000        186.000000
# mean    678.994624      113.059140         53.924731
# std     377.892770       76.481842         47.424076
# min     101.000000        4.000000          2.000000
# 25%     305.250000       55.250000         18.000000
# 50%     712.500000       87.000000         34.000000
# 75%    1011.750000      157.000000         77.000000
# max    1312.000000      349.000000        225.000000
#
#        male_part_time_high_school  male_employed  male_home_and_high_school  \
# count                  186.000000     186.000000                 186.000000
# mean                    15.543011      33.150538                  12.397849
# std                     27.494487      27.427130                  27.780857
# min                      0.000000       1.000000                   0.000000
# 25%                      2.000000      14.000000                   1.000000
# ...

# %%
df3 = pd.read_csv('../../Data/School/0001/school.csv')

# %%
df3.describe()
# Out:
#          school_id  male_graduates  male_high_school  \
# count   188.000000      188.000000        188.000000
# mean    680.478723      122.484043         63.978723
# std     379.449354      118.710427        108.055341
# min     101.000000        4.000000          2.000000
# 25%     305.750000       55.750000         18.000000
# 50%     712.500000       88.000000         34.500000
# 75%    1012.250000      159.000000         79.750000
# max    1312.000000      999.000000        999.000000
#
#        male_part_time_high_school  male_employed  male_home_and_high_school  \
# count                  188.000000     188.000000                 188.000000
# mean                    16.430851      43.425532                  13.319149
# std                     28.662904     103.030237                  29.032423
# min                      0.000000       1.000000                   0.000000
# 25%                      2.000000      14.000000                   1.000000
# ...

# %%
df2.male_part_time_high_school.replace(99,0)
df2.male_home_and_high_school.replace(99,0)
df2.male_home.replace(99,0)
df2.male_others.replace(99,0)
# Out:
# 0      3
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 183    0
# 184    1
# 185    0
# 186    1
# 187    1
# Name: male_others, Length: 186, dtype: int64

# %%
df2.describe()
# Out:
#          school_id  male_graduates  male_high_school  \
# count   186.000000      186.000000        186.000000
# mean    678.994624      113.059140         53.924731
# std     377.892770       76.481842         47.424076
# min     101.000000        4.000000          2.000000
# 25%     305.250000       55.250000         18.000000
# 50%     712.500000       87.000000         34.000000
# 75%    1011.750000      157.000000         77.000000
# max    1312.000000      349.000000        225.000000
#
#        male_part_time_high_school  male_employed  male_home_and_high_school  \
# count                  186.000000     186.000000                 186.000000
# mean                    15.543011      33.150538                  12.397849
# std                     27.494487      27.427130                  27.780857
# min                      0.000000       1.000000                   0.000000
# 25%                      2.000000      14.000000                   1.000000
# ...

# %%
df2.describe()
# Out:
#          school_id  male_graduates  male_high_school  \
# count   186.000000      186.000000        186.000000
# mean    678.994624      113.059140         53.924731
# std     377.892770       76.481842         47.424076
# min     101.000000        4.000000          2.000000
# 25%     305.250000       55.250000         18.000000
# 50%     712.500000       87.000000         34.000000
# 75%    1011.750000      157.000000         77.000000
# max    1312.000000      349.000000        225.000000
#
#        male_part_time_high_school  male_employed  male_home_and_high_school  \
# count                  186.000000     186.000000                 186.000000
# mean                    15.543011      33.150538                  12.397849
# std                     27.494487      27.427130                  27.780857
# min                      0.000000       1.000000                   0.000000
# 25%                      2.000000      14.000000                   1.000000
# ...

# %%
df2.loc[:,'male_part_time_high_school']
#df2.male_home_and_high_school.replace(99,0)
#df2.male_home.replace(99,0)
#df2.male_others.replace(99,0)
# Out:
# 0      18
# 1       6
# 2       8
# 3      18
# 4      18
#        ..
# 183     3
# 184     4
# 185     1
# 186     0
# 187     0
# Name: male_part_time_high_school, Length: 186, dtype: int64

# %%
df2.male_part_time_high_school[df2.male_part_time_high_school == 99] = 0

# %%
df2.describe()
# Out:
#          school_id  male_graduates  male_high_school  \
# count   186.000000      186.000000        186.000000
# mean    678.994624      113.059140         53.924731
# std     377.892770       76.481842         47.424076
# min     101.000000        4.000000          2.000000
# 25%     305.250000       55.250000         18.000000
# 50%     712.500000       87.000000         34.000000
# 75%    1011.750000      157.000000         77.000000
# max    1312.000000      349.000000        225.000000
#
#        male_part_time_high_school  male_employed  male_home_and_high_school  \
# count                  186.000000     186.000000                 186.000000
# mean                     6.494624      33.150538                  12.397849
# std                      7.469757      27.427130                  27.780857
# min                      0.000000       1.000000                   0.000000
# 25%                      1.000000      14.000000                   1.000000
# ...

# %%
gender = ['male','female']
attribute = ['_part_time_high_school','_home_and_high_school','_home','_others']
df2[df2.loc[:,gender[0]+attribute[1]]==99].loc[:,gender[0]+attribute[1]].replace(99,0)
# Out:
# 9      0
# 35     0
# 54     0
# 73     0
# 79     0
# 80     0
# 143    0
# 144    0
# 146    0
# 150    0
# 157    0
# 158    0
# 160    0
# 163    0
# 168    0
# 171    0
# 182    0
# Name: male_home_and_high_school, dtype: int64

# %%
gender = ['male','female']
attribute = ['_part_time_high_school','_home_and_high_school','_home','_others']
columns = []
for item_g in gender:
    for item_a in attribute:
        columns.append(item_g+item_a)
columns
# Out:
# ['male_part_time_high_school',
#  'male_home_and_high_school',
#  'male_home',
#  'male_others',
#  'female_part_time_high_school',
#  'female_home_and_high_school',
#  'female_home',
#  'female_others']

# %%
gender = ['male','female']
attribute = ['_part_time_high_school','_home_and_high_school','_home','_others']
columns = []
for i in range(len(gender)):
    for j in range(len(attribute)):
        columns.append(gender[i]+attribute[j])
columns

# %%
df2 = pd.read_csv('../../Data/School/0001/school.csv')

null_major = 999
null_minor = 99 

# Remove empty row
df2 = df2[df2.male_graduates != null_major]

# Replace null values
gender = ['male','female']
attribute_minor= ['_part_time_high_school','_home_and_high_school','_home','_others']

for item_g in gender:
    for item_a in attribute_minor:
        column=item_g+item_a
        df2.loc[:,column][df2.loc[:,column]==null_minor]=0
        
df2.describe()

# Check 
checksum = []
attrimute_major = ['_high_school','_employed']
attribute_all = attribute_major+attribute_minor

for item_g in gender:
    for item_a in attribute_all:
        index = gender.index(item_g)
        column=item_g+item_a
        checksum += df2.loc[:,column]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-369-68bd28b4f542> in <module>
#      27         index = gender.index(item_g)
#      28         column=item_g+item_a
# ---> 29         checksum += df2.loc[:,column]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(left, right)
#    1046
#    1047         with np.errstate(all="ignore"):
# -> 1048             result = na_op(lvalues, rvalues)
#    1049         return construct_result(
#    1050             left, result, index=left.index, name=res_name, dtype=None
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#     966
#     967         try:
# --> 968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
#     970             result = masked_arith_op(x, y, op)
#
# ...

# %%
df2 = pd.read_csv('../../Data/School/0001/school.csv')

null_major = 999
null_minor = 99 

# Remove empty rows
df2 = df2[df2.male_graduates != null_major]

# Replace null values with 0
gender = ['male', 'female']
categories_major = ['_high_school', '_employed']
categories_minor = ['_part_time_high_school', '_home_and_high_school',
                    '_home', '_others']
major_or_minor = ['_major','_minor']

for item_g in gender:
    for item_m in major_or_minor:
            for item_a in vars()['categories' + item_m]:
                column = item_g+item_a
                df.loc[:, column][df.loc[:, column] == vars()['null'+item_m]] = 0
        
df2.describe()

# Compaore subtotal of categories and graduates
categories_major = ['_high_school','_employed']
categories_all = categories_major+categories_minor

for item_g in gender:
    df2[item_g+'_subtotal']=df2.loc[:,item_g+categories_all[0]:item_g+categories_all[-1]].sum(axis=1)
    vars()[item_g+'_subtotal_neq_graduates_index']=df2[df2[item_g+'_subtotal']!=df2[item_g+'_graduates']].index

# %%
for item_g in gender:
    del df2[item_g+'_subtotal']

# %%
df2
# Out:
#      school_id  male_graduates  male_high_school  male_part_time_high_school  \
# 0          101             172                43                          18
# 1          102             141                64                           6
# 2          103             300               218                           8
# 3          104             219               115                          18
# 4          105             220                67                          18
# ..         ...             ...               ...                         ...
# 183       1308              52                30                           3
# 184       1309              29                13                           4
# 185       1310              27                 6                           1
# 186       1311              32                 3                           0
# 187       1312              23                 8                           0
#
# ...

# %%
a
# Out:
# 0      172
# 1      141
# 2      300
# 3      219
# 4      220
#       ...
# 183     52
# 184     29
# 185     27
# 186     32
# 187     23
# Length: 186, dtype: int64

# %%
df2.loc[:,columns[1]][df2.loc[:,columns[1]]==99]= 0
df2.describe()
# Out:
#          school_id  male_graduates  male_high_school  \
# count   188.000000      188.000000        188.000000
# mean    680.478723      122.484043         63.978723
# std     379.449354      118.710427        108.055341
# min     101.000000        4.000000          2.000000
# 25%     305.750000       55.750000         18.000000
# 50%     712.500000       88.000000         34.500000
# 75%    1012.250000      159.000000         79.750000
# max    1312.000000      999.000000        999.000000
#
#        male_part_time_high_school  male_employed  male_home_and_high_school  \
# count                  188.000000     188.000000                  188.00000
# mean                    16.430851      43.425532                    3.31383
# std                     28.662904     103.030237                    3.79028
# min                      0.000000       1.000000                    0.00000
# 25%                      2.000000      14.000000                    0.00000
# ...

# %%
df2[df2.loc[:,'male'+'_home'] == 99]
gender[1]+attribute[2]
# Out:
# 'female_home'

# %%
df2.describe()
# Out:
#          school_id  male_graduates  male_high_school  \
# count   188.000000      188.000000        188.000000
# mean    680.478723      122.484043         63.978723
# std     379.449354      118.710427        108.055341
# min     101.000000        4.000000          2.000000
# 25%     305.750000       55.750000         18.000000
# 50%     712.500000       88.000000         34.500000
# 75%    1012.250000      159.000000         79.750000
# max    1312.000000      999.000000        999.000000
#
#        male_part_time_high_school  male_employed  male_home_and_high_school  \
# count                  188.000000     188.000000                 188.000000
# mean                    16.430851      43.425532                  13.319149
# std                     28.662904     103.030237                  29.032423
# min                      0.000000       1.000000                   0.000000
# 25%                      2.000000      14.000000                   1.000000
# ...

# %%
df3.describe()
# Out:
#          school_id  male_graduates  male_high_school  \
# count   188.000000      188.000000        188.000000
# mean    680.478723      122.484043         63.978723
# std     379.449354      118.710427        108.055341
# min     101.000000        4.000000          2.000000
# 25%     305.750000       55.750000         18.000000
# 50%     712.500000       88.000000         34.500000
# 75%    1012.250000      159.000000         79.750000
# max    1312.000000      999.000000        999.000000
#
#        male_part_time_high_school  male_employed  male_home_and_high_school  \
# count                  188.000000     188.000000                 188.000000
# mean                    16.430851      43.425532                  13.319149
# std                     28.662904     103.030237                  29.032423
# min                      0.000000       1.000000                   0.000000
# 25%                      2.000000      14.000000                   1.000000
# ...

# %%
df = pd.read_csv('../../Data/School/0001/school_cleaned.csv')

# %%
df.describe()
# Out:
#          school_id  male_graduates  male_high_school  \
# count   186.000000      186.000000        186.000000
# mean    678.994624      113.059140         53.924731
# std     377.892770       76.481842         47.424076
# min     101.000000        4.000000          2.000000
# 25%     305.250000       55.250000         18.000000
# 50%     712.500000       87.000000         34.000000
# 75%    1011.750000      157.000000         77.000000
# max    1312.000000      349.000000        225.000000
#
#        male_part_time_high_school  male_employed  male_home_and_high_school  \
# count                  186.000000     186.000000                 186.000000
# mean                     6.494624      33.150538                   3.349462
# std                      7.469757      27.427130                   3.794936
# min                      0.000000       1.000000                   0.000000
# 25%                      1.000000      14.000000                   0.250000
# ...

# %%
df = pd.read_csv('../../Data/School/0001/school_cleaned.csv')

# Replace null values with 0
gender = ['male', 'female']
categories = ['_high_school', '_employed','_part_time_high_school', '_home_and_high_school',
                    '_home', '_others']

for item_g in gender:
        for item_c in categories :
            column = item_g + item_c
            df[column+'_percentage']=df[column]/df[item_g+'_graduates']*100

# %%
df.iloc[:,-12:-1].describe()
# Out:
#        male_high_school_percentage  male_employed_percentage  \
# count                   186.000000                186.000000
# mean                     43.577104                 28.825751
# std                      15.681478                 11.849145
# min                       9.375000                  2.272727
# 25%                      32.258851                 20.270270
# 50%                      43.352317                 27.893773
# 75%                      54.953704                 36.632420
# max                      80.254777                 70.909091
#
#        male_part_time_high_school_percentage  \
# count                             186.000000
# mean                                5.044724
# std                                 4.465355
# min                                 0.000000
# 25%                                 1.684054
# 50%                                 4.255319
# 75%                                 7.756410
# max                                22.222222
#
# ...

# %%
school_id= df.school_id.unique()
# Out:
# array([ 101,  102,  103,  104,  105,  111,  112,  113,  114,  115,  116,
#         201,  202,  203,  204,  205,  206,  211,  212,  213,  214,  221,
#         222,  223,  231,  232,  233,  241,  242,  243,  244,  245,  251,
#         252,  261,  262,  263,  271,  272,  281,  282,  283,  301,  302,
#         303,  304,  305,  306,  311,  312,  321,  322,  323,  324,  325,
#         326,  327,  331,  332,  333,  334,  336,  337,  401,  402,  403,
#         404,  405,  406,  407,  501,  502,  503,  504,  511,  512,  513,
#         601,  602,  603,  604,  605,  606,  611,  612,  613,  701,  702,
#         703,  704,  705,  711,  712,  713,  721,  722,  723,  724,  801,
#         802,  803,  804,  805,  806,  807,  808,  809,  810,  811,  812,
#         813,  814,  815,  816,  901,  902,  903,  904,  905,  906,  907,
#         908,  909,  910,  911,  912,  913,  914,  915,  916,  917,  918,
#         919, 1001, 1002, 1003, 1004, 1005, 1011, 1012, 1013, 1014, 1015,
# ...

# %%
test =df.school_id.astype(str).str.match('school_id[2][0-9]$')

# %%
df[test]
# Out:
# Empty DataFrame
# Columns: [school_id, male_graduates, male_high_school, male_part_time_high_school, male_employed, male_home_and_high_school, male_home, male_others, female_graduates, female_high_school, female_part_time_high_school, female_employed, female_home_and_high_school, female_home, female_others]
# Index: []

# %%
df = pd.read_csv('../../Data/School/0001/school_cleaned.csv')

df.school_id.unique()
school_classification_temp=[item[:-1] for item in df.school_id.unique().astype(str)]
school_classification_temp=np.unique(np.array(school_classification_temp).astype(int))

# %%
df = pd.read_csv('../../Data/School/0001/school_cleaned.csv')

df.school_id.unique()
school_classification_temp=[item[:-1] for item in df.school_id.unique().astype(str)]
school_classification_temp=np.unique(np.array(school_classification_temp).astype(int))

# %%
school_classification_temp
# Out:
# array([ 10,  11,  20,  21,  22,  23,  24,  25,  26,  27,  28,  30,  31,
#         32,  33,  40,  50,  51,  60,  61,  70,  71,  72,  80,  81,  90,
#         91, 100, 101, 102, 110, 111, 120, 121, 130, 131])

# %%
search=school_classification_temp[27].astype(str)+'[0-9]$'

# %%
bool_match =df.school_id.astype(str).str.match(search)

# %%
df['school_classification']=0

# %%
df.loc[bool_match,'school_classification'] = 1

# %%
for item  in school_classification_temp:
    search=item.astype(str)+'[0-9]$'
    bool_match =df.school_id.astype(str).str.match(search)
    df.loc[bool_match,'school_classification']=item

# %%
df
# Out:
#      school_id  male_graduates  male_high_school  male_part_time_high_school  \
# 0          101             172                43                          18
# 1          102             141                64                           6
# 2          103             300               218                           8
# 3          104             219               115                          18
# 4          105             220                67                          18
# ..         ...             ...               ...                         ...
# 181       1308              52                30                           3
# 182       1309              29                13                           4
# 183       1310              27                 6                           1
# 184       1311              32                 3                           0
# 185       1312              23                 8                           0
#
# ...

# %%
search2='9'+'[0-9]'
bool_match =df.school_id.astype(str).str.match(search2)

# %%
df[bool_match]
# Out:
#      school_id  male_graduates  male_high_school  male_part_time_high_school  \
# 114        901             140                77                           3
# 115        902              74                34                           3
# 116        903             156                70                           3
# 117        904             135                60                          12
# 118        905              44                16                           2
# 119        906              42                18                           3
# 120        907              52                23                           3
# 121        908             117                52                           6
# 122        909              56                17                           0
# 123        910             164                72                           2
# 124        911              61                22                           0
# ...

# %%
df.describe()
# Out:
#          school_id  male_graduates  male_high_school  \
# count   186.000000      186.000000        186.000000
# mean    678.994624      113.059140         53.924731
# std     377.892770       76.481842         47.424076
# min     101.000000        4.000000          2.000000
# 25%     305.250000       55.250000         18.000000
# 50%     712.500000       87.000000         34.000000
# 75%    1011.750000      157.000000         77.000000
# max    1312.000000      349.000000        225.000000
#
#        male_part_time_high_school  male_employed  male_home_and_high_school  \
# count                  186.000000     186.000000                 186.000000
# mean                     6.494624      33.150538                   3.349462
# std                      7.469757      27.427130                   3.794936
# min                      0.000000       1.000000                   0.000000
# 25%                      1.000000      14.000000                   0.250000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
_ = plt.hist(df.male_graduates)
_ = plt.xlabel('male_graduates')
_ = plt.ylabel('counts')
_ = plt.title('Histgram of male_graduates')
plt.show()

# %%
def plot_histogram(df, column_name, bins=20):
    sns.set()
    _ = plt.hist(df[column_name], bins= bins)
    _ = plt.xlabel(column_name)
    _ = plt.ylabel('counts')
    _ = plt.title('Histgram of ' + column_name)
    plt.show()
    
plot_histogram(df, 'male_graduates')

# %%
plot_histogram(df, 'female_graduates')

# %%
def create_share(df, gender, category):
    df[gender+ category+'_share']=df[gender+ category]/df[gender+'_graduates']

# %%
create_share(df, 'male','_home')

# %%
df.male_employed_share
# Out:
# 0      0.529070
# 1      0.439716
# 2      0.186667
# 3      0.365297
# 4      0.604545
#          ...
# 181    0.211538
# 182    0.241379
# 183    0.148148
# 184    0.187500
# 185    0.304348
# Name: male_employed_share, Length: 186, dtype: float64

# %%
plot_histogram(df,'male_employed_share')

# %%
plot_histogram(df, 'male_home_share')

# %%
create_share(df,'male','_high_school')

# %%
sns.scatterplot(x="male_employed_share", y='male_home_share', size='male_graduates',sizes=(20, 200), data=df)

# %%
sns.regplot(x="male_employed_share", y='male_home_share',data=df)

# %%
sns.scatterplot(x='male_high_school_share',y='male_home_share',size='male_graduates',sizes=(20, 200), data=df)

# %%
sns.regplot(x='male_high_school_share',y='male_home_share',data=df)

# %%
sns.scatterplot(x='male_high_school_share',y='male_employed_share',size='male_graduates',sizes=(20, 200),data=df)

# %%
sns.regplot(x='male_high_school_share',y='male_employed_share',data=df)

# %%
create_share(df, 'female','_employed')
create_share(df,'female','_high_school')

# %%
create_share(df, 'female', '_home')

# %%
plot_histogram(df,'female_home_share')

# %%
sns.scatterplot(x='male_home_share',y='female_home_share',data=df, sizes=(20,200), size='total_graduates', hue='school_classification')

# %%
sns.scatterplot(x='male_employed_share',y='female_employed_share',data=df, sizes=(20,200), size='total_graduates',hue='school_classification')

# %%
sns.scatterplot(x='male_high_school_share',y='female_high_school_share',data=df, sizes=(20,200), size='total_graduates')

# %%
def add_male_and_female(category):
    df['total'+category]=df['male'+category]+df['female'+category]
add_male_and_female('_graduates')

# %%
df.total_graduates
# Out:
# 0      329
# 1      272
# 2      517
# 3      387
# 4      452
#       ...
# 181    102
# 182     60
# 183     41
# 184     62
# 185     48
# Name: total_graduates, Length: 186, dtype: int64

# %%
df2
# Out:
#                        male_graduates  male_high_school  \
# school_classification
# 10                               1052               507
# 11                               1145               559
# 20                                860               387
# 21                                930               504
# 22                                782               413
# 23                                547               322
# 24                               1113               505
# 25                                324               161
# 26                                510               298
# 27                                393               161
# 28                                268               132
# 30                                589               202
# 31                                364               132
# 32                                489               111
# 33                                548               254
# ...

# %%
df2['male_high_school_ratio']=df2['male_high_school']/df2['male_graduates']
df2['male_employed_ratio']=df2['male_employed']/df2['male_graduates']
df2['male_home_ratio']=df2['male_home']/df2['male_graduates']

# %%
df2.male_high_school_ratio
# Out:
# school_classification
# 10     0.481939
# 11     0.488210
# 20     0.450000
# 21     0.541935
# 22     0.528133
# 23     0.588665
# 24     0.453729
# 25     0.496914
# 26     0.584314
# 27     0.409669
# 28     0.492537
# 30     0.342954
# 31     0.362637
# 32     0.226994
# 33     0.463504
# 40     0.507521
# 50     0.193717
# 51     0.276596
# 60     0.650927
# 61     0.512727
# 70     0.619048
# 71     0.466667
# 72     0.546992
# 80     0.385064
# 81     0.465116
# 90     0.449755
# 91     0.374424
# 100    0.551425
# 101    0.584906
# 102    0.439331
# 110    0.580122
# 111    0.681102
# 120    0.358736
# 121    0.398496
# 130    0.414110
# 131    0.207317
# Name: male_high_school_ratio, dtype: float64

# %%
df2.male_employed_ratio
# Out:
# school_classification
# 10     0.401141
# 11     0.312664
# 20     0.373256
# 21     0.305376
# 22     0.332481
# 23     0.268739
# 24     0.297394
# 25     0.370370
# 26     0.294118
# 27     0.315522
# 28     0.231343
# 30     0.351443
# 31     0.398352
# 32     0.316973
# 33     0.240876
# 40     0.364290
# 50     0.492147
# 51     0.216312
# 60     0.244519
# 61     0.280000
# 70     0.177945
# 71     0.292308
# 72     0.298872
# 80     0.233372
# 81     0.193314
# 90     0.317402
# 91     0.279954
# 100    0.215613
# 101    0.195755
# 102    0.359833
# 110    0.217039
# 111    0.153543
# 120    0.252788
# 121    0.210526
# 130    0.288344
# 131    0.207317
# Name: male_employed_ratio, dtype: float64

# %%
df2.male_home_ratio
# Out:
# school_classification
# 10     0.041825
# 11     0.072489
# 20     0.070930
# 21     0.075269
# 22     0.044757
# 23     0.063985
# 24     0.076370
# 25     0.027778
# 26     0.037255
# 27     0.083969
# 28     0.156716
# 30     0.169779
# 31     0.120879
# 32     0.361963
# 33     0.177007
# 40     0.042511
# 50     0.240838
# 51     0.368794
# 60     0.053963
# 61     0.105455
# 70     0.116541
# 71     0.128205
# 72     0.046992
# 80     0.249708
# 81     0.264535
# 90     0.153186
# 91     0.225806
# 100    0.117720
# 101    0.101415
# 102    0.154812
# 110    0.121704
# 111    0.118110
# 120    0.289963
# 121    0.338346
# 130    0.150307
# 131    0.451220
# Name: male_home_ratio, dtype: float64

# %%
df2.describe()
# Out:
#        male_graduates  male_high_school  male_part_time_high_school  \
# count       36.000000         36.000000                   36.000000
# mean       584.138889        278.611111                   33.555556
# std        324.874934        171.886221                   28.482019
# min         82.000000         17.000000                    1.000000
# 25%        325.500000        139.500000                   11.500000
# 50%        535.000000        270.000000                   28.500000
# 75%        809.250000        386.250000                   40.000000
# max       1529.000000        776.000000                  124.000000
#
#        male_employed  male_home_and_high_school   male_home  male_others  \
# count      36.000000                  36.000000   36.000000    36.000000
# mean      171.277778                  17.305556   73.527778     9.888889
# std       116.129881                  14.409956   53.209283    12.063588
# ...

# %%
df.columns[1:]
# Out:
# Index(['male_graduates', 'male_high_school', 'male_part_time_high_school',
#        'male_employed', 'male_home_and_high_school', 'male_home',
#        'male_others', 'female_graduates', 'female_high_school',
#        'female_part_time_high_school', 'female_employed',
#        'female_home_and_high_school', 'female_home', 'female_others',
#        'school_classification', 'male_employed_share', 'male_home_share',
#        'female_home_share', 'total_graduates', 'male_high_school_share',
#        'female_employed_share', 'female_high_school_share'],
#       dtype='object')
