# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
file = '../../../Data/Workers/1207/1207.csv'
df = pd.read_csv(file, low_memory = False)

# %%
df[df.recruit1 == 1].describe()
# Out:
#           companyn    companyn2             id         agey    birthyear  \
# count  2396.000000  2396.000000    2396.000000  2396.000000  2396.000000
# mean     27.571369    27.571369  193783.952003    28.815109  1932.386060
# std      12.475191    12.475191   64520.842512     7.198269   285.754078
# min       1.000000     1.000000      33.000000    15.000000  1892.000000
# 25%      22.000000    22.000000  170564.250000    24.000000  1918.000000
# 50%      22.000000    22.000000  172624.500000    27.000000  1924.000000
# 75%      32.000000    32.000000  230043.000000    33.000000  1927.000000
# max      64.000000    64.000000  370828.000000    99.000000  9999.000000
#
#             famrel          sex    edudegree      eduspec      edugrad  ...  \
# count  2396.000000  2396.000000  2396.000000  2396.000000  2396.000000  ...
# mean     18.488314     1.085559    44.823873    13.306344     2.241653  ...
# std      35.911656     2.011809   119.816833    14.570871    10.714848  ...
# ...
