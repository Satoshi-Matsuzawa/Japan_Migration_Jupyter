# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
directory = '../../../../Data/School/0001/'
file_name_label = '0001_otsu label.txt'

file_label = os.path.join(directory, file_name_label)
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /Users/satoshi/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
file_name_data = '0001_otsu.dat'

file_data = os.path.join(directory, file_name_data)
df = pd.read_csv(file_data, sep = '\t', error_bad_lines = False)

# %%
df
# Out:
#        gakkou  seibetu  q2_1 q2_2 q2_3 q2_4 q2_5 q2_6  q3.1  q3.2  ...  \
# 0         101        1     2                              1     3  ...
# 1         101        1     2                              1     2  ...
# 2         101        1     5                              1     1  ...
# 3         101        1     1                              2     2  ...
# 4         101        1     5                              2     3  ...
# ...       ...      ...   ...  ...  ...  ...  ...  ...   ...   ...  ...
# 13098    1312        2     5    4                         2     3  ...
# 13099    1312        2     5    4                         2     2  ...
# 13100    1312        2     5    4                         2     1  ...
# 13101    1312        2     5    4                         2     2  ...
# 13102    1312        2     5    4                         2     1  ...
#
#        q4.3.2  q6   q7    q8  q9.1.2  q9.2   q10  q11  q12  q13
# 0          11  33    1  1000    2014     1  5650    2    4
# 1           4  36   10  1000    2013     1  5300    2    1
# 2           5  36    1  1000    2021     1  6700    2    1
# 3           5  36    1  1000    2011     1  6000    2    1
# 4           6  36    1  1000    2011     1  5800    2    1    1
# ...       ...  ..  ...   ...     ...   ...   ...  ...  ...  ...
# 13098       9  22   93   200    1074     9  3500    1    3
# 13099       7  22   93   200    1073     9  3500    1    3
# 13100       6  22   93   200    1073     9  3500    1    3
# 13101       7  22  150   120    1071     9  1000    1    9
# 13102       3   7  160     6    6014     2     0    1    5
#
# [13103 rows x 22 columns]

# %%
abbrevaiton = {
    'GNDR': 'gender',
    'M':'male',
    'F':'female',
    'GDN':'guardian',
    'AFF':'Agriculture Forestry and Fishing',
    'MFG':'Manufacturing',
    'COM':'Commerce',
    'SRV':'Service',
    'LI':'Light Industry',
    'HI':'Heavy Industry',
    'ORS':'Others',
    'WC':'White Collar',
    'UE':'Unemployed',
    'UNK':'Unknown',
    'RSN':'reason',
    'SZ':'size',
    'FB':'family business',
    'URB':'urban',
    'WF':'Water Front',
    'RUR':'rural',
    'SUB':'suburb',
    'SCH':'school',
    'CONN':'connection',
    'DCT':'direct',
    'COMM':'commute',
    'CH':'channel',
    'SAL':'salary',
    'LCTN':'location',
}

# %%
gndr = {
    1:'M',
    2:'F'
}

# %%
gdn_occ = {
    1:'AFF',
    2:'AFF',
    3:'AFF',
    4:'MFG',
    5:'MFG',
    6:'SRV',
    7:'SRV',
    8:'SRV',
    9:'SRV',
    10:'WC',
    11:'ORS',
    12:'ORS',
    13:'ORS',
    14:'UE',
    15:'UK',
    99:'UNK',
}

# %%
heir = {
    1:'Y',
    2:'N',
    9:'UNK'
}

# %%
gdn_rel = {
    1: 'Eldest son / daughter',
    2: 'Second son / daughter',
    3: 'Third son / daughter',
    4: 'Fourth or more',
    5: 'Brother / Sister',
    6: 'Nephew Niece',
    7: 'UNK'
}

# %%
ind = {
    1: 'AFF',
    2: 'AFF',
    3: 'AFF',
    4: 'MFG_ORS',
    5: 'MFG_ORS',
    6: 'MFG_ORS',
    7: 'COM',
    8: 'SRV',
    9: 'COM',
    10: 'SRV',
    11: 'COM',
    12: 'COM',
    13: 'COM',
    14: 'SRV',
    15: 'SRV',
    16: 'SRV',
    17: 'SRV',
    18: 'SRV',
    19: 'SRV',
    20: 'LI',
    21: 'LI',
    22: 'LI',
    23: 'LI',
    24: 'LI',
    25: 'LI',
    26: 'LI',
    27: 'LI',
    29: 'HI',
    30: 'HI',
    31: 'LI',
    32: 'LI',
    33: 'HI',
    34: 'HI',
    35: 'HI',
    36: 'HI',
    37: 'HI',
    38: 'HI',
    39: 'MFG_ORS',
    40: 'MFG_ORS',
    41: 'SRV',
    42: 'UNK',
    43: 'UNK',
    99: 'UNK'
}

# %%
lctn = {
    1: 'WFN',
    9: 'SUB',
    10: 'WFN',
    11: 'SUB',
    12: 'SUB',
    13: 'WFN',
    14: 'WFN',
    15: 'WFS',
    16: 'SUB',
    17: 'WFS',
    18: 'WFS',
    19: 'SUB',
    20: 'SUB',
    30: 'SUB',
    40: 'WFS',
    41: 'WFS',
    42: 'RUR',
    50: 'RUR',
    60: 'SUB',
    70: 'SUB',
    80: 'SUB',
    90: 'RUR',
    91: 'RUR',
    92: 'RUR',
    93: 'RUR',
    101: 'RUR',
    102: 'RUR',
    110: 'RUR',
    120: 'RUR',
    130: 'RUR',
    140: 'RUR',
    150: 'TYO',
    160: 'ORS',
    999: 'UNK',
}

# %%
ch = {
    1: 'SCH',
    2: 'SCH',
    3: 'SCH',
    4: 'CONN',
    5: 'CONN',
    6: 'CONN',
    7: 'DCT',
    8: 'ORS',
    9: 'DCT',
    99: 'UNK',
}

# %%
comm = {
    1: 'N',
    2: 'Y',
    9: 'UNK',
}

# %%
crs = {
    1: 'COM',
    2: 'IND',
    3: 'AGR',
    4: 'HHE',
    5: 'ENG',
    6: 'ORS',
}

# %%
def apply_dict(col, dictionary, df = df):
    df[col] = df[col].map(dictionary)

# %%
col_dict = [['seibetu', gndr],
            ['q2_1', crs],
            ['q2_2', crs],
            ['q2_3', crs],
            ['q2_4', crs],
            ['q2_5', crs],
            ['q2_6', crs],
            ['q3.1', heir],
            ['q3.2', gdn_rel],
            ['q4.1', gdn_occ],
            ['q6', ind],
            ['q7', lctn],
            ['q12', ch],
            ['q11', comm],
           ]

# %%
for item in col_dict:
    col = item[0]
    dictionary = item[1]
    apply_dict(col, dictionary)

# %%
col_names = {
    'seibetu' : 'gndr',
    'q2_1': 'crs1',
    'q2_2': 'crs2',
    'q2_3': 'crs3',
    'q2_4': 'crs4',
    'q2_5': 'crs5',
    'q2_6': 'crs6',
    'q3.1' : 'heir',
    'q3.2' : 'gdn_rel',
    'q4.1' : 'gdn_occ',
    'q4.3.2': 'fam_sz',
    'q6': 'ind',
    'q7': 'lctn',
    'q8': 'frm_sz',
    'q10': 'sal',
    'q11': 'comm',
    'q12': 'ch',
}

# %%
df.rename(columns = col_names, inplace=True)

# %%
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
df[df.gndr == 'M'].gdn_rel.value_counts().plot(kind = 'bar', ax =axs2[0])
df[df.gndr == 'F'].gdn_rel.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
fig2.suptitle('Relationship to guardian')
plt.show()

# %%
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
df[df.gndr == 'M'].gdn_occ.value_counts().plot(kind = 'bar', ax =axs2[0])
df[df.gndr == 'F'].gdn_occ.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
fig2.suptitle('Occupation of guardian')
plt.show()

# %%
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
df[df.ch == 'SCH'].gdn_occ.value_counts().plot(kind = 'bar', ax =axs2[0])
df[df.ch == 'CONN'].gdn_occ.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('SCH')
axs2[1].title.set_text('CONN')
fig2.suptitle('Occupation of guardian')
plt.show()

# %%
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
df[(df.ch == 'SCH') & (df.gdn_occ == 'AFF')].ind.value_counts().plot(kind = 'bar', ax =axs2[0])
df[(df.ch == 'CONN') & (df.gdn_occ == 'AFF')].ind.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('SCH')
axs2[1].title.set_text('CONN')
fig2.suptitle("Industries for farmers' children")
plt.show()

# %%
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
df[(df.ch == 'SCH') & (df.gdn_occ == 'MFG')].ind.value_counts().plot(kind = 'bar', ax =axs2[0])
df[(df.ch == 'CONN') & (df.gdn_occ == 'MFG')].ind.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('School')
axs2[1].title.set_text('Connection')
fig2.suptitle("Industries for MFG worker's children")
plt.show()

# %%
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
df[df.ch == 'SCH'].lctn.value_counts().plot(kind = 'bar', ax =axs2[0])
df[df.ch == 'CONN'].lctn.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('School')
axs2[1].title.set_text('Connection')
fig2.suptitle('Location of the job')
plt.show()

# %%
fig2, axs2 = plt.subplots(1,2, figsize=(10, 4))
df[df.ch == 'SCH'].lctn.value_counts().sort_index().plot.pie(ax =axs2[0],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
df[df.ch == 'CONN'].lctn.value_counts().sort_index().plot.pie(ax = axs2[1],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
axs2[0].title.set_text('School')
axs2[1].title.set_text('Connection')
axs2[0].axis('equal')
axs2[1].axis('equal')
plt.axis('off')
fig2.suptitle('Location of the job')
plt.tight_layout()
plt.savefig('../../../../Graphs/Employed/Location.pgf')

plt.show()

# %%
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
df[df.ch == 'SCH'].ind.value_counts().plot(kind = 'bar', ax =axs2[0])
df[df.ch == 'CONN'].ind.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('School')
axs2[1].title.set_text('Connection')
fig2.suptitle('Industries')
plt.show()

# %%
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
df[df.gndr == 'M'].heir.value_counts().plot(kind = 'bar', ax =axs2[0])
df[df.gndr == 'F'].heir.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
fig2.suptitle('Heir or not')
plt.show()

# %%
ax = df.gdn_occ.value_counts().plot(kind = 'bar')
ax.title.set_text("Guardian's occupation")

# %%
ax = df.ch.value_counts().plot(kind = 'bar')
ax.title.set_text("Employment channel")

# %%
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
df[(df.ch == 'SCH') & (df.gdn_occ == 'AFF')].ind.value_counts().plot(kind = 'bar', ax =axs2[0])
df[(df.ch == 'CONN') & (df.gdn_occ == 'AFF')].ind.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('SCH')
axs2[1].title.set_text('CONN')
fig2.suptitle("Industries for farmers' children")
plt.show()

# %%
_df = df[(df.ch == 'SCH') & (df.gdn_occ == 'AFF')]

# %%
_df = df[['gndr', 'ind']][(df.ch == 'SCH') & (df.gdn_occ == 'AFF')]

# %%
_df_plot = df.groupby(['gndr', 'ind']).size().reset_index().pivot(columns='gndr', index ='ind', values=0)

# %%
fig = plt.figure()
axs = _df_plot.plot.bar(subplots = True)
axs[0].title.set_text('Female')
axs[1].title.set_text('Male')
fig.suptitle("Industries for farmers' children")
plt.show()

# %%
import seaborn as sns

# %%
sns.countplot(x = 'ind', hue = 'gndr', data = _df)
plt.title("Industries for farmers' children")
# Out:
# Text(0.5, 1.0, "Industries for farmers' children")

# %%
_df_sch = df[['gndr', 'ind']][(df.ch == 'SCH') & (df.gdn_occ == 'AFF')]

# %%
_df_con = df[['gndr', 'ind']][(df.ch == 'CONN') & (df.gdn_occ == 'AFF')]

# %%
sns.countplot(x = _df_sch.ind, hue = _df_sch.gndr)
plt.title('Jobs mediated by school')
# Out:
# Text(0.5, 1.0, 'Jobs mediated by school')

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (10, 6))
sns.countplot(x = _df_sch.ind, hue = _df_sch.gndr, ax = ax1)
sns.countplot(x = _df_con.ind, hue = _df_con.gndr, ax = ax2)

# %%
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
df[df.gndr == 'M'].crs1.value_counts().plot(kind = 'bar', ax =axs2[0])
df[df.gndr == 'F'].crs1.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
fig2.suptitle('Choice of the elective')
plt.show()

# %%
_df = df
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
_df[_df.gndr == 'M'].crs1.value_counts().plot(kind = 'bar', ax =axs2[0])
_df[_df.gndr == 'F'].crs1.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
fig2.suptitle('Choice of the elective of students')
plt.show()

# %%
_df = df

fig2, axs2 = plt.subplots(1,2, figsize=(6, 4))
_df[_df.gndr == 'M'].crs1.value_counts().sort_index().plot.pie(ax =axs2[0],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
_df[_df.gndr == 'F'].crs1.value_counts().sort_index().plot.pie(ax = axs2[1],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
axs2[0].axis('off')
axs2[1].axis('off')
plt.axis('off')
#fig2.suptitle('Elective')
plt.tight_layout()
plt.savefig('../../../../Graphs/Employed/ElectiveAll.pgf')
plt.show()

# %%
_df = df[df.ind == 'HI']
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
_df[_df.gndr == 'M'].crs1.value_counts().plot(kind = 'bar', ax =axs2[0])
_df[_df.gndr == 'F'].crs1.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
fig2.suptitle('Choice of the elective of student who got HI jobs')
plt.show()

# %%
_df = df[df.ind == 'HI']

fig2, axs2 = plt.subplots(1,2, figsize=(6, 4))
_df[_df.gndr == 'M'].crs1.value_counts().sort_index().plot.pie(ax =axs2[0],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
_df[_df.gndr == 'F'].crs1.value_counts().sort_index().plot.pie(ax = axs2[1],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
axs2[0].axis('off')
axs2[1].axis('off')
plt.axis('off')
#fig2.suptitle('Choice of the elective of student who got HI jobs')
plt.tight_layout()
plt.savefig('../../../../Graphs/Employed/ElectiveHI.pgf')


plt.show()

# %%
_df = df[df.ind == 'LI']
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
_df[_df.gndr == 'M'].crs1.value_counts().plot(kind = 'bar', ax =axs2[0])
_df[_df.gndr == 'F'].crs1.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
fig2.suptitle('Choice of the elective of student who got LI jobs')
plt.show()

# %%
_df = df[df.ind == 'LI']

fig2, axs2 = plt.subplots(1,2, figsize=(10, 4))
_df[_df.gndr == 'M'].crs1.value_counts().sort_index().plot.pie(ax =axs2[0],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
_df[_df.gndr == 'F'].crs1.value_counts().sort_index().plot.pie(ax = axs2[1],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
axs2[0].axis('equal')
axs2[1].axis('equal')
plt.axis('off')
fig2.suptitle('Choice of the elective of student who got HI jobs')
plt.tight_layout()
plt.show()

# %%
_df = df[df.ind == 'COM']
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
_df[_df.gndr == 'M'].crs1.value_counts().plot(kind = 'bar', ax =axs2[0])
_df[_df.gndr == 'F'].crs1.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
fig2.suptitle('Choice of the elective of student who got COM jobs')
plt.show()

# %%
_df = df[df.ind == 'COM']

fig2, axs2 = plt.subplots(1,2, figsize=(10, 4))
_df[_df.gndr == 'M'].crs1.value_counts().sort_index().plot.pie(ax =axs2[0],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
_df[_df.gndr == 'F'].crs1.value_counts().sort_index().plot.pie(ax = axs2[1],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
axs2[0].axis('equal')
axs2[1].axis('equal')
plt.axis('off')
fig2.suptitle('Choice of the elective of student who got COM jobs')
plt.tight_layout()
plt.show()

# %%
_df = df[df.ind == 'SRV']
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
_df[_df.gndr == 'M'].crs1.value_counts().plot(kind = 'bar', ax =axs2[0])
_df[_df.gndr == 'F'].crs1.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
fig2.suptitle('Choice of the elective of student who got SRV jobs')
plt.show()

# %%
_df = df[df.ind == 'SRV']

fig2, axs2 = plt.subplots(1,2, figsize=(10, 4))
_df[_df.gndr == 'M'].crs1.value_counts().sort_index().plot.pie(ax =axs2[0],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
_df[_df.gndr == 'F'].crs1.value_counts().sort_index().plot.pie(ax = axs2[1],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
axs2[0].axis('equal')
axs2[1].axis('equal')
plt.axis('off')
fig2.suptitle('Choice of the elective of student who got SRV jobs')
plt.tight_layout()
plt.show()

# %%
_df = df[(df.ind == 'HI') & (df.ch == 'SCH')]
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
_df[_df.gndr == 'M'].crs1.value_counts().plot(kind = 'bar', ax =axs2[0])
_df[_df.gndr == 'F'].crs1.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
fig2.suptitle('Course selection of student who got HI jobs mediated by SCH')
plt.show()

# %%
_df = df[(df.ind == 'HI') & (df.ch == 'SCH')]

fig2, axs2 = plt.subplots(1,2, figsize=(10, 4))
_df[_df.gndr == 'M'].crs1.value_counts().sort_index().plot.pie(ax =axs2[0],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
_df[_df.gndr == 'F'].crs1.value_counts().sort_index().plot.pie(ax = axs2[1],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
axs2[0].axis('equal')
axs2[1].axis('equal')
plt.axis('off')
fig2.suptitle('Course selection of student who got HI jobs mediated by SCH')
plt.tight_layout()
plt.show()

# %%
_df = df[(df.ch == 'SCH')]
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
_df[_df.gndr == 'M'].crs1.value_counts().plot(kind = 'bar', ax =axs2[0])
_df[_df.gndr == 'F'].crs1.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
fig2.suptitle('Course selection of student who got jobs mediated by SCH')
plt.show()

# %%
_df = df[ (df.ch == 'SCH')]

fig2, axs2 = plt.subplots(1,2, figsize=(10, 4))
_df[_df.gndr == 'M'].crs1.value_counts().sort_index().plot.pie(ax =axs2[0],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
_df[_df.gndr == 'F'].crs1.value_counts().sort_index().plot.pie(ax = axs2[1],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
axs2[0].axis('equal')
axs2[1].axis('equal')
plt.axis('off')
fig2.suptitle('Course selection of student who got obs mediated by SCH')
plt.tight_layout()
plt.show()

# %%
_df = df[(df.ch == 'CONN')]
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
_df[_df.gndr == 'M'].crs1.value_counts().plot(kind = 'bar', ax =axs2[0])
_df[_df.gndr == 'F'].crs1.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
fig2.suptitle('Course selection of student who got jobs mediated by CONN')
plt.show()

# %%
_df = df[ (df.ch == 'CONN')]

fig2, axs2 = plt.subplots(1,2, figsize=(10, 4))
_df[_df.gndr == 'M'].crs1.value_counts().sort_index().plot.pie(ax =axs2[0],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
_df[_df.gndr == 'F'].crs1.value_counts().sort_index().plot.pie(ax = axs2[1],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
axs2[0].axis('equal')
axs2[1].axis('equal')
plt.axis('off')
fig2.suptitle('Course selection of student who got obs mediated by CONN')
plt.tight_layout()
plt.show()

# %%
_df = df[df.gdn_occ == 'AFF']
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
_df[_df.gndr == 'M'].crs1.value_counts().plot(kind = 'bar', ax =axs2[0])
_df[_df.gndr == 'F'].crs1.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
fig2.suptitle('Choice of the elective of students, occ of guardian  AFF')
plt.show()

# %%
_df = df[df.gdn_occ == 'AFF']
fig2, axs2 = plt.subplots(1,2, figsize=(10, 4))
_df[_df.gndr == 'M'].crs1.value_counts().sort_index().plot.pie(ax =axs2[0],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
_df[_df.gndr == 'F'].crs1.value_counts().sort_index().plot.pie(ax = axs2[1],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
axs2[0].axis('equal')
axs2[1].axis('equal')
plt.axis('off')
fig2.suptitle('Choice of the elective of students')
plt.tight_layout()
plt.show()

# %%
_df = df[(df.ind == 'HI') & (df.gdn_occ == 'AFF')]
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
_df[_df.gndr == 'M'].crs1.value_counts().plot(kind = 'bar', ax =axs2[0])
_df[_df.gndr == 'F'].crs1.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
fig2.suptitle('Choice of the elective of student who got HI jobs: parents AFF')
plt.show()

# %%
_df = df[(df.ind == 'HI') & (df.gdn_occ == 'AFF')]
fig2, axs2 = plt.subplots(1,2, figsize=(10, 4))
_df[_df.gndr == 'M'].crs1.value_counts().sort_index().plot.pie(ax =axs2[0],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
_df[_df.gndr == 'F'].crs1.value_counts().sort_index().plot.pie(ax = axs2[1],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
axs2[0].axis('equal')
axs2[1].axis('equal')
plt.axis('off')
fig2.suptitle('Choice of the course:Jobs HI, Parents AFF')
plt.tight_layout()
plt.show()

# %%
_df = df[(df.ind == 'LI') & (df.gdn_occ == 'AFF')]
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
_df[_df.gndr == 'M'].crs1.value_counts().plot(kind = 'bar', ax =axs2[0])
_df[_df.gndr == 'F'].crs1.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
fig2.suptitle('Choice of the elective: LI jobs, AFF parents')
plt.show()

# %%
_df = df[(df.ind == 'LI') & (df.gdn_occ == 'AFF')]
fig2, axs2 = plt.subplots(1,2, figsize=(10, 4))
_df[_df.gndr == 'M'].crs1.value_counts().sort_index().plot.pie(ax =axs2[0],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
_df[_df.gndr == 'F'].crs1.value_counts().sort_index().plot.pie(ax = axs2[1],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
axs2[0].axis('equal')
axs2[1].axis('equal')
plt.axis('off')
fig2.suptitle('Choice of the elective: LI jobs, AFF parents')
plt.tight_layout()
plt.show()

# %%
_df = df[(df.ind == 'COM') & (df.gdn_occ == 'AFF')]
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
_df[_df.gndr == 'M'].crs1.value_counts().plot(kind = 'bar', ax =axs2[0])
_df[_df.gndr == 'F'].crs1.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
fig2.suptitle('Choice of the elective: COM jobs, AFF parents')
plt.show()

# %%
_df = df[(df.ind == 'COM') & (df.gdn_occ == 'AFF')]


fig2, axs2 = plt.subplots(1,2, figsize=(10, 4))
_df[_df.gndr == 'M'].crs1.value_counts().sort_index().plot.pie(ax =axs2[0],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
_df[_df.gndr == 'F'].crs1.value_counts().sort_index().plot.pie(ax = axs2[1],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
axs2[0].axis('equal')
axs2[1].axis('equal')
plt.axis('off')
fig2.suptitle('Choice of the elective: COM jobs, AFF parents')
plt.tight_layout()
plt.show()

# %%
_df = df[(df.ind == 'SRV') & (df.gdn_occ == 'AFF')]
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
_df[_df.gndr == 'M'].crs1.value_counts().plot(kind = 'bar', ax =axs2[0])
_df[_df.gndr == 'F'].crs1.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
fig2.suptitle('Choice of the elective: SRV jobs, AFF parents')
plt.show()

# %%
_df = df[(df.ind == 'SRV') & (df.gdn_occ == 'AFF')]

fig2, axs2 = plt.subplots(1,2, figsize=(10, 4))
_df[_df.gndr == 'M'].crs1.value_counts().sort_index().plot.pie(ax =axs2[0],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
_df[_df.gndr == 'F'].crs1.value_counts().sort_index().plot.pie(ax = axs2[1],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
axs2[0].axis('equal')
axs2[1].axis('equal')
plt.axis('off')
fig2.suptitle('Choice of the elective: SRV jobs, AFF parents')
plt.tight_layout()
plt.show()

# %%
_df = df[(df.ind == 'HI') & (df.ch == 'SCH')]
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
_df[_df.gndr == 'M'].crs1.value_counts().plot(kind = 'bar', ax =axs2[0])
_df[_df.gndr == 'F'].crs1.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
fig2.suptitle('Course selection of student who got HI jobs mediated by SCH')
plt.show()

# %%
_df = df[(df.ind == 'HI') & (df.ch == 'SCH')]

fig2, axs2 = plt.subplots(1,2, figsize=(10, 4))
_df[_df.gndr == 'M'].crs1.value_counts().sort_index().plot.pie(ax =axs2[0],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
_df[_df.gndr == 'F'].crs1.value_counts().sort_index().plot.pie(ax = axs2[1],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
axs2[0].axis('equal')
axs2[1].axis('equal')
plt.axis('off')
fig2.suptitle('Course selection of student who got HI jobs mediated by SCH')
plt.tight_layout()
plt.show()

# %%
_df = df[(df.ch == 'SCH')]
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
_df[_df.gndr == 'M'].crs1.value_counts().plot(kind = 'bar', ax =axs2[0])
_df[_df.gndr == 'F'].crs1.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
fig2.suptitle('Course selection of student who got jobs mediated by SCH')
plt.show()

# %%
_df = df[ (df.ch == 'SCH')]

fig2, axs2 = plt.subplots(1,2, figsize=(10, 4))
_df[_df.gndr == 'M'].crs1.value_counts().sort_index().plot.pie(ax =axs2[0],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
_df[_df.gndr == 'F'].crs1.value_counts().sort_index().plot.pie(ax = axs2[1],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
axs2[0].axis('equal')
axs2[1].axis('equal')
plt.axis('off')
fig2.suptitle('Course selection of student who got obs mediated by SCH')
plt.tight_layout()
plt.show()

# %%
_df = df[(df.ch == 'CONN')]
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
_df[_df.gndr == 'M'].crs1.value_counts().plot(kind = 'bar', ax =axs2[0])
_df[_df.gndr == 'F'].crs1.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
fig2.suptitle('Course selection of student who got jobs mediated by CONN')
plt.show()

# %%
_df = df[ (df.ch == 'CONN')]

fig2, axs2 = plt.subplots(1,2, figsize=(10, 4))
_df[_df.gndr == 'M'].crs1.value_counts().sort_index().plot.pie(ax =axs2[0],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
_df[_df.gndr == 'F'].crs1.value_counts().sort_index().plot.pie(ax = axs2[1],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
axs2[0].axis('equal')
axs2[1].axis('equal')
plt.axis('off')
fig2.suptitle('Course selection of student who got obs mediated by CONN')
plt.tight_layout()
plt.show()

# %%
_df = df[df.sal != 99999]
fig, ax = plt.subplots()
num_bins = 20
ax = _df[_df.ind == 'HI'].sal.plot.hist(bins = num_bins, alpha = 0.6, label = 'HI', density = True) # density = True
ax = _df[_df.ind == 'LI'].sal.plot.hist(bins = num_bins, alpha = 0.6, color = 'r', label = 'LI', density = True) # density = True
ax.set_ylabel('Frequency')
ax.set_xlabel('Monthly salary')
plt.title('Starting Salary')

plt.legend()
plt.show()

# %%
_df = df[df.sal != 99999]
fig, ax = plt.subplots()
num_bins = 20
ax = _df[_df.ind == 'HI'].sal.plot.hist(bins = num_bins, alpha = 0.6, label = 'HI', density = True) # density = True
ax = _df[_df.ind == 'COM'].sal.plot.hist(bins = num_bins, alpha = 0.6, color = 'g', label = 'COM', density = True) # density = True
ax.set_ylabel('Frequency')
ax.set_xlabel('Monthly salary')
plt.title('Starting Salary')

plt.legend()
plt.show()

# %%
_df = df[df.sal != 99999]
fig, ax = plt.subplots()
num_bins = 20
ax = _df[_df.ind == 'HI'].sal.plot.hist(bins = num_bins, alpha = 0.6, label = 'HI', density = True) # density = True
ax = _df[_df.ind == 'SRV'].sal.plot.hist(bins = num_bins, alpha = 0.6, color = 'm', label = 'COM', density = True) # density = True
ax.set_ylabel('Frequency')
ax.set_xlabel('Monthly salary')
plt.title('Starting Salary')

plt.legend()
plt.show()

# %%
_df = df[df.sal != 99999]
fig, ax = plt.subplots()
num_bins = 20
ax = _df[_df.ind == 'HI'].sal.plot.hist(bins = num_bins, alpha = 0.6, label = 'HI', density = True) # density = True
ax = _df[_df.ind == 'LI'].sal.plot.hist(bins = num_bins, alpha = 0.6, color = 'r', label = 'LI', density = True) # density = True
ax = _df[_df.ind == 'COM'].sal.plot.hist(bins = num_bins, alpha = 0.6, color = 'g', label = 'COM', density = True) # density = True
ax = _df[_df.ind == 'SRV'].sal.plot.hist(bins = num_bins, alpha = 0.6, color = 'm', label = 'COM', density = True) # density = True
ax.set_ylabel('Frequency')
ax.set_xlabel('Monthly salary')
plt.title('Starting Salary')

plt.legend()
plt.show()

# %%
_df.sal.describe()
# Out:
# count    10772.000000
# mean      3734.454697
# std       1380.735741
# min          0.000000
# 25%       3000.000000
# 50%       3700.000000
# 75%       4500.000000
# max      12500.000000
# Name: sal, dtype: float64

# %%
_df = df[(df.crs1  == 'IND')]
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
_df[_df.gndr == 'M'].ind.value_counts().plot(kind = 'bar', ax =axs2[0])
_df[_df.gndr == 'F'].ind.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
fig2.suptitle('Jobs for students chose IND')
plt.show()

# %%
_df = df[ (df.crs1 == 'IND')]

fig2, axs2 = plt.subplots(1,2, figsize=(6, 4))
_df[_df.gndr == 'M'].ind.value_counts().sort_index().plot.pie(ax =axs2[0],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
_df[_df.gndr == 'F'].ind.value_counts().sort_index().plot.pie(ax = axs2[1],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
axs2[0].axis('off')
axs2[1].axis('off')
plt.axis('off')
#fig2.suptitle('Jobs for students chose IND')

plt.tight_layout()
plt.savefig('../../../../Graphs/Employed/ElectiveIND.pgf')
plt.show()

# %%
_df = df[(df.crs1  == 'ENG')]
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
_df[_df.gndr == 'M'].ind.value_counts().plot(kind = 'bar', ax =axs2[0])
_df[_df.gndr == 'F'].ind.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
fig2.suptitle('Jobs for students chose ENG')

plt.show()

# %%
_df = df[ (df.crs1 == 'ENG')]

fig2, axs2 = plt.subplots(1,2, figsize=(10, 4))
_df[_df.gndr == 'M'].ind.value_counts().sort_index().plot.pie(ax =axs2[0],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
_df[_df.gndr == 'F'].ind.value_counts().sort_index().plot.pie(ax = axs2[1],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
axs2[0].axis('off')
axs2[1].axis('off')
plt.axis('off')
fig2.suptitle('Jobs for students chose ENG')

plt.tight_layout()
plt.savefig('../../../../Graphs/Employed/ElectiveENG.pgf')


plt.show()

# %%
_df = df[(df.crs1  == 'AGR')]
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
_df[_df.gndr == 'M'].ind.value_counts().plot(kind = 'bar', ax =axs2[0])
_df[_df.gndr == 'F'].ind.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
fig2.suptitle('Jobs for students chose AGR')

plt.show()

# %%
_df = df[ (df.crs1 == 'AGR')]

fig2, axs2 = plt.subplots(1,2, figsize=(10, 4))
_df[_df.gndr == 'M'].ind.value_counts().sort_index().plot.pie(ax =axs2[0],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
_df[_df.gndr == 'F'].ind.value_counts().sort_index().plot.pie(ax = axs2[1],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
axs2[0].axis('equal')
axs2[1].axis('equal')
plt.axis('off')
fig2.suptitle('Jobs for students chose AGR')

plt.tight_layout()
plt.show()

# %%
_df = df[(df.crs1  == 'COM')]
fig2, axs2 = plt.subplots(1,2, figsize=(8, 4))
_df[_df.gndr == 'M'].ind.value_counts().plot(kind = 'bar', ax =axs2[0])
_df[_df.gndr == 'F'].ind.value_counts().plot(kind = 'bar', ax = axs2[1])
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
fig2.suptitle('Jobs for students chose COM')

plt.show()

# %%
_df = df[ (df.crs1 == 'COM')]

fig2, axs2 = plt.subplots(1,2, figsize=(10, 4))
_df[_df.gndr == 'M'].ind.value_counts().sort_index().plot.pie(ax =axs2[0],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
_df[_df.gndr == 'F'].ind.value_counts().sort_index().plot.pie(ax = axs2[1],autopct='%1.1f%%',
shadow=True, startangle=140, cmap = 'Set3')
axs2[0].title.set_text('Male')
axs2[1].title.set_text('Female')
axs2[0].axis('equal')
axs2[1].axis('equal')
plt.axis('off')
fig2.suptitle('Jobs for students chose COM')

plt.tight_layout()
plt.show()
