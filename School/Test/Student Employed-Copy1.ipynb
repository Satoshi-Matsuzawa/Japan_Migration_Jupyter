# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

df = pd.read_csv('../../../../Data/School/0001/student_employed.csv')

# %%
df.head()
# Out:
#    school_id  gender  course_1 course_2 course_3 course_4 course_5 course_6  \
# 0        101       1         2
# 1        101       1         2
# 2        101       1         5
# 3        101       1         1
# 4        101       1         5
#
#    heir  relation_to_the_guardian  ...  family_size  industry  location  \
# 0     1                         3  ...           11        33         1
# 1     1                         2  ...            4        36        10
# 2     1                         1  ...            5        36         1
# 3     2                         2  ...            5        36         1
# 4     2                         3  ...            6        36         1
#
#    firm_size  job_description  trainee_or_apprentice salary  \
# 0       1000             2014                      1   5650
# 1       1000             2013                      1   5300
# 2       1000             2021                      1   6700
# ...

# %%
df.describe()
# Out:
#           school_id        gender      course_1          heir  \
# count  13103.000000  13103.000000  13103.000000  13103.000000
# mean     487.531710      1.444478      4.410746      6.631153
# std      347.656474      0.496927      2.305366      3.435277
# min      101.000000      1.000000      1.000000      1.000000
# 25%      221.000000      1.000000      2.000000      2.000000
# 50%      324.000000      1.000000      4.000000      9.000000
# 75%      804.000000      2.000000      5.000000      9.000000
# max     1312.000000      2.000000      9.000000      9.000000
#
#        relation_to_the_guardian  occupation_of_the_guardian   living_standard  \
# count              13103.000000                13103.000000      13103.000000
# mean                   3.054491                    7.288102          3.955583
# std                    2.653775                    4.797275          2.912007
# min                    1.000000                    1.000000          1.000000
# ...

# %%
df[df.location==999]
# Out:
#        school_id  gender  course_1 course_2 course_3 course_4 course_5  \
# 78           101       1         2
# 84           101       1         1
# 101          101       1         2
# 147          101       2         4
# 186          102       1         2
# ...          ...     ...       ...      ...      ...      ...      ...
# 13015       1308       1         3
# 13017       1308       2         1
# 13018       1308       2         1
# 13029       1308       2         4
# 13037       1309       1         5
#
#       course_6  heir  relation_to_the_guardian  ...  family_size  industry  \
# 78                 2                         2  ...            5        37
# 84                 1                         1  ...            4        40
# 101                2                         2  ...            6        43
# 147                1                         1  ...            6        36
# 186                2                         2  ...            6        43
# ...

# %%
from statsmodels.graphics.mosaicplot import mosaic
mosaic(df[(df.employment_channel!=99) & (df.commute_or_live_alone!=9)].sort_values('employment_channel'),  ['employment_channel' , 'commute_or_live_alone'])
plt.show()

# %%
sns.catplot(x='employment_channel', y='commute_or_live_alone' ,kind="boxen",data=df[(df.employment_channel!=99) & (df.commute_or_live_alone!=9)])

# %%
df[df.commute_or_live_alone!=9].describe()
# Out:
#           school_id        gender      course_1          heir  \
# count  12649.000000  12649.000000  12649.000000  12649.000000
# mean     489.803305      1.442486      4.378291      6.659420
# std      348.244283      0.496701      2.295199      3.425206
# min      101.000000      1.000000      1.000000      1.000000
# 25%      221.000000      1.000000      2.000000      2.000000
# 50%      326.000000      1.000000      4.000000      9.000000
# 75%      805.000000      2.000000      5.000000      9.000000
# max     1312.000000      2.000000      9.000000      9.000000
#
#        relation_to_the_guardian  occupation_of_the_guardian   living_standard  \
# count              12649.000000                12649.000000      12649.000000
# mean                   3.059056                    7.268796          3.933671
# std                    2.654148                    4.801928          2.898223
# min                    1.000000                    1.000000          1.000000
# ...

# %%
sns.set()
sns.distplot(df[df.firm_size!=9999].firm_size)

# %%
sns.distplot(df[df.salary!=99999].salary)

# %%
sns.scatterplot(x='firm_size',y='salary',data=df[(df.salary!=99999)&(df.firm_size!=9999)])

# %%
sns.catplot(x='employment_channel', y='salary' ,kind="boxen",data=df[(df.employment_channel!=99) & (df.salary!=99999)])

# %%
#sns.catplot(x='employment_channel', y='location' ,kind="violin",inner="stick", split=True,
#            palette="pastel", hue='gender', cut=0,
#            data=df[(df.employment_channel!=99) & (df.location!=999)])

# %%
from statsmodels.graphics.mosaicplot import mosaic
mosaic(df[(df.employment_channel!=99) & (df.location!=999)].sort_values('location'),  ['employment_channel' , 'location'])
plt.show()

# %%
sns.catplot(x="employment_channel", y="location", hue='location', kind="bar", data=df[(df.employment_channel!=99) & (df.location!=999)]);

# %%
df[['employment_channel','location']]
# Out:
#        employment_channel  location
# 0                       4         1
# 1                       1        10
# 2                       1         1
# 3                       1         1
# 4                       1         1
# ...                   ...       ...
# 13098                   3        93
# 13099                   3        93
# 13100                   3        93
# 13101                   9       150
# 13102                   5       160
#
# [13103 rows x 2 columns]

# %%
df[df.firm_size==9999]
# Out:
#        school_id  gender  course_1 course_2 course_3 course_4 course_5  \
# 29           101       1         2
# 84           101       1         1
# 101          101       1         2
# 150          101       2         4
# 186          102       1         2
# ...          ...     ...       ...      ...      ...      ...      ...
# 13017       1308       2         1
# 13018       1308       2         1
# 13024       1308       2         4
# 13029       1308       2         4
# 13036       1309       1         5
#
#       course_6  heir  relation_to_the_guardian  ...  family_size  industry  \
# 29                 2                         1  ...            7        34
# 84                 1                         1  ...            4        40
# 101                2                         2  ...            6        43
# 150                2                         2  ...            7        32
# 186                2                         2  ...            6        43
# ...

# %%
df[df.salary==99999]
# Out:
#        school_id  gender  course_1 course_2 course_3 course_4 course_5  \
# 84           101       1         1
# 100          101       1         5
# 101          101       1         2
# 102          101       1         1
# 186          102       1         2
# ...          ...     ...       ...      ...      ...      ...      ...
# 13024       1308       2         4
# 13029       1308       2         4
# 13062       1310       2         4
# 13065       1310       2         4
# 13067       1310       2         4
#
#       course_6  heir  relation_to_the_guardian  ...  family_size  industry  \
# 84                 1                         1  ...            4        40
# 100                1                         2  ...            4         7
# 101                2                         2  ...            6        43
# 102                2                         2  ...            6         7
# 186                2                         2  ...            6        43
# ...

# %%
df[df.employment_channel==99].describe()
# Out:
#          school_id       gender     course_1         heir  \
# count  1109.000000  1109.000000  1109.000000  1109.000000
# mean    628.981064     1.441839     4.434626     6.825969
# std     371.900173     0.496830     2.402712     3.343647
# min     101.000000     1.000000     1.000000     1.000000
# 25%     281.000000     1.000000     2.000000     2.000000
# 50%     702.000000     1.000000     4.000000     9.000000
# 75%     908.000000     2.000000     5.000000     9.000000
# max    1310.000000     2.000000     9.000000     9.000000
#
#        relation_to_the_guardian  occupation_of_the_guardian   living_standard  \
# count               1109.000000                 1109.000000       1109.000000
# mean                   3.279531                    6.580703          4.630298
# std                    2.848989                    5.490065          3.216948
# min                    1.000000                    1.000000          1.000000
# ...

# %%
df_channel = df[df.employment_channel!=99]

# %%
df_channel_and_salary=df_channel[df_channel.salary!=99999]

# %%
df_channel_and_salary.describe()
# Out:
#           school_id        gender      course_1          heir  \
# count  10309.000000  10309.000000  10309.000000  10309.000000
# mean     476.618489      1.450286      4.394219      6.617325
# std      349.868829      0.497547      2.269483      3.442405
# min      101.000000      1.000000      1.000000      1.000000
# 25%      213.000000      1.000000      2.000000      2.000000
# 50%      311.000000      1.000000      4.000000      9.000000
# 75%      805.000000      2.000000      5.000000      9.000000
# max     1312.000000      2.000000      9.000000      9.000000
#
#        relation_to_the_guardian  occupation_of_the_guardian   living_standard  \
# count              10309.000000                10309.000000      10309.000000
# mean                   3.000194                    7.266272          3.673683
# std                    2.594770                    4.549389          2.730707
# min                    1.000000                    1.000000          1.000000
# ...

# %%
cond = (df.employment_channel!=99) & (df.salary!=99999)

# %%
df[cond].describe()
# Out:
#           school_id        gender      course_1          heir  \
# count  10309.000000  10309.000000  10309.000000  10309.000000
# mean     476.618489      1.450286      4.394219      6.617325
# std      349.868829      0.497547      2.269483      3.442405
# min      101.000000      1.000000      1.000000      1.000000
# 25%      213.000000      1.000000      2.000000      2.000000
# 50%      311.000000      1.000000      4.000000      9.000000
# 75%      805.000000      2.000000      5.000000      9.000000
# max     1312.000000      2.000000      9.000000      9.000000
#
#        relation_to_the_guardian  occupation_of_the_guardian   living_standard  \
# count              10309.000000                10309.000000      10309.000000
# mean                   3.000194                    7.266272          3.673683
# std                    2.594770                    4.549389          2.730707
# min                    1.000000                    1.000000          1.000000
# ...

# %%
df_channel_and_salary[df_channel_and_salary.location==999]
# Out:
#        school_id  gender  course_1 course_2 course_3 course_4 course_5  \
# 78           101       1         2
# 147          101       2         4
# 248          102       1         2
# 249          102       1         2
# 250          102       2         5        1
# ...          ...     ...       ...      ...      ...      ...      ...
# 10994        914       1         3
# 12759       1211       2         4
# 12798       1301       1         2
# 12821       1301       2         4
# 13037       1309       1         5
#
#       course_6  heir  relation_to_the_guardian  ...  family_size  industry  \
# 78                 2                         2  ...            5        37
# 147                1                         1  ...            6        36
# 248                2                         2  ...            5         5
# 249                1                         1  ...            6         5
# 250                2                         1  ...            6        30
# ...

# %%
df_channel_and_salary[df_channel_and_salary.firm_size==9999]
# Out:
#        school_id  gender  course_1 course_2 course_3 course_4 course_5  \
# 29           101       1         2
# 150          101       2         4
# 237          102       1         5        2
# 248          102       1         2
# 249          102       1         2
# ...          ...     ...       ...      ...      ...      ...      ...
# 12846       1302       2         4
# 12847       1302       2         4
# 12849       1302       2         4
# 12850       1302       2         4
# 13036       1309       1         5
#
#       course_6  heir  relation_to_the_guardian  ...  family_size  industry  \
# 29                 2                         1  ...            7        34
# 150                2                         2  ...            7        32
# 237                2                         4  ...            8        11
# 248                2                         2  ...            5         5
# 249                1                         1  ...            6         5
# ...

# %%
df[df.firm_size!=9999].describe()
# Out:
#           school_id        gender      course_1          heir  \
# count  10371.000000  10371.000000  10371.000000  10371.000000
# mean     498.484524      1.439880      4.339215      6.606499
# std      358.632167      0.496396      2.231463      3.442139
# min      101.000000      1.000000      1.000000      1.000000
# 25%      221.000000      1.000000      2.000000      2.000000
# 50%      326.000000      1.000000      4.000000      9.000000
# 75%      810.000000      2.000000      5.000000      9.000000
# max     1312.000000      2.000000      9.000000      9.000000
#
#        relation_to_the_guardian  occupation_of_the_guardian   living_standard  \
# count              10371.000000                10371.000000      10371.000000
# mean                   2.945039                    7.107415          3.691640
# std                    2.545491                    4.682456          2.743834
# min                    1.000000                    1.000000          1.000000
# ...

# %%
df2=pd.get_dummies(df, columns=['employment_channel']).groupby('school_id').sum()

# %%
df2
# Out:
#            gender  course_1  heir  relation_to_the_guardian  \
# school_id
# 101           255       606   314                       370
# 102           204       563   239                       272
# 103           184       435  1116                       225
# 104           251       632  1566                       325
# 105           426      1425  2565                       712
# ...           ...       ...   ...                       ...
# 1308           42        78    49                       252
# 1309           41       107   155                        64
# 1310           21        56    25                        36
# 1311           26        68    30                        52
# 1312           29        90    34                        38
#
#            occupation_of_the_guardian   living_standard  family_size  \
# school_id
# 101                              1246               378         1145
# 102                               967               320          736
# ...

# %%
df_channels=df2.iloc[:,-10:]

# %%
df_channels.describe()
# Out:
#        employment_channel_1  employment_channel_2  employment_channel_3  \
# count            188.000000            188.000000            188.000000
# mean               2.388298             18.063830             17.494681
# std               11.133765             25.610747             31.143191
# min                0.000000              0.000000              0.000000
# 25%                0.000000              2.000000              1.000000
# 50%                0.000000              7.000000              6.000000
# 75%                0.000000             20.250000             16.000000
# max              110.000000            114.000000            192.000000
#
#        employment_channel_4  employment_channel_5  employment_channel_6  \
# count            188.000000            188.000000            188.000000
# mean               8.872340              4.569149             11.186170
# std               15.665101              7.112579             21.386497
# ...

# %%
df_channels[df_channels.employment_channel_1!=0].count()
# Out:
# employment_channel_1     26
# employment_channel_2     26
# employment_channel_3     26
# employment_channel_4     26
# employment_channel_5     26
# employment_channel_6     26
# employment_channel_7     26
# employment_channel_8     26
# employment_channel_9     26
# employment_channel_99    26
# dtype: int64

# %%
df_channels[df_channels.employment_channel_2!=0].count()
# Out:
# employment_channel_1     152
# employment_channel_2     152
# employment_channel_3     152
# employment_channel_4     152
# employment_channel_5     152
# employment_channel_6     152
# employment_channel_7     152
# employment_channel_8     152
# employment_channel_9     152
# employment_channel_99    152
# dtype: int64

# %%
df_channels[df_channels.employment_channel_3!=0].count()
# Out:
# employment_channel_1     143
# employment_channel_2     143
# employment_channel_3     143
# employment_channel_4     143
# employment_channel_5     143
# employment_channel_6     143
# employment_channel_7     143
# employment_channel_8     143
# employment_channel_9     143
# employment_channel_99    143
# dtype: int64

# %%
df_channels['school_and_shokuan']=df_channels.iloc[:,0]+df_channels.iloc[:,1]+df_channels.iloc[:,2]

# %%
df_channels['family_and_connection']=df_channels.iloc[:,3]+df_channels.iloc[:,4]+df_channels.iloc[:,5]

# %%
df_channels = df_channels.iloc[:,-2:].reset_index()

# %%
df_school = pd.read_csv('../../../../Data/School/0001/school_cleaned.csv')

# %%
df_school
# Out:
#      school_id  male_graduates  male_high_school  male_part_time_high_school  \
# 0          101             172                43                          18
# 1          102             141                64                           6
# 2          103             300               218                           8
# 3          104             219               115                          18
# 4          105             220                67                          18
# ..         ...             ...               ...                         ...
# 181       1308              52                30                           3
# 182       1309              29                13                           4
# 183       1310              27                 6                           1
# 184       1311              32                 3                           0
# 185       1312              23                 8                           0
#
# ...

# %%
df_merged = pd.merge(df_school, df_channels, on='school_id')

# %%
df_merged
# Out:
#      school_id  male_graduates  male_high_school  male_part_time_high_school  \
# 0          101             172                43                          18
# 1          102             141                64                           6
# 2          103             300               218                           8
# 3          104             219               115                          18
# 4          105             220                67                          18
# ..         ...             ...               ...                         ...
# 181       1308              52                30                           3
# 182       1309              29                13                           4
# 183       1310              27                 6                           1
# 184       1311              32                 3                           0
# 185       1312              23                 8                           0
#
# ...

# %%
df_merged['total_employed']=df_merged['male_employed']+df_merged['female_employed']

# %%
df_merged['shokuan_share']=df_merged['school_and_shokuan']/df_merged['total_employed']

# %%
df_merged['connection_share']=df_merged['family_and_connection']/df_merged['total_employed']

# %%
df_merged['total_graduates']=df_merged['male_graduates']+df_merged['female_graduates']

# %%
df_merged.describe()
# Out:
#          school_id  male_graduates  male_high_school  \
# count   186.000000      186.000000        186.000000
# mean    678.994624      113.059140         53.924731
# std     377.892770       76.481842         47.424076
# min     101.000000        4.000000          2.000000
# 25%     305.250000       55.250000         18.000000
# 50%     712.500000       87.000000         34.000000
# 75%    1011.750000      157.000000         77.000000
# max    1312.000000      349.000000        225.000000
#
#        male_part_time_high_school  male_employed  male_home_and_high_school  \
# count                  186.000000     186.000000                 186.000000
# mean                     6.494624      33.150538                   3.349462
# std                      7.469757      27.427130                   3.794936
# min                      0.000000       1.000000                   0.000000
# 25%                      1.000000      14.000000                   0.250000
# ...

# %%
def create_share(df, gender, category):
    df[gender+ category+'_share']=df[gender+ category]/df[gender+'_graduates']

# %%
create_share(df_merged, 'male','_high_school')

# %%
sns.set()
sns.scatterplot(x="male_high_school_share", y='shokuan_share', size='male_graduates',sizes=(20, 200), data=df_merged)

# %%
create_share(df_merged, 'male','_home')

# %%
sns.regplot(x="male_high_school_share", y='shokuan_share', data=df_merged)

# %%
create_share(df_merged,'male','_employed')
sns.scatterplot(x="male_employed_share", y='shokuan_share', size='male_graduates',sizes=(20, 200), data=df_merged)

# %%
df_merged['shokuan_share'].describe()
# Out:
# count    186.000000
# mean       0.533510
# std        0.309186
# min        0.000000
# 25%        0.311090
# 50%        0.527778
# 75%        0.738265
# max        1.666667
# Name: shokuan_share, dtype: float64

# %%
sns.distplot(df_merged[df_merged.shokuan_share <= 1].shokuan_share)

# %%
df_merged[df_merged.shokuan_share > 1]
# Out:
#      school_id  male_graduates  male_high_school  male_part_time_high_school  \
# 6          112             178                95                          35
# 8          114             188               120                          10
# 12         202              90                31                          11
# 30         244             268               194                          21
# 37         271             201                87                          23
# 46         305              79                37                           6
# 81         605             153                97                          17
# 130        917              90                31                          20
# 146       1019              32                17                           3
#
#      male_employed  male_home_and_high_school  male_home  male_others  \
# 6               24                          0         20            4
# ...

# %%
sns.distplot(df_merged[df_merged.shokuan_share <= 1].school_and_shokuan)

# %%
sns.distplot(df_merged[df_merged.shokuan_share <= 1].family_and_connection)

# %%
sns.distplot(df_merged[df_merged.shokuan_share <= 1].connection_share)

# %%
fig, ax = plt.subplots(figsize = (5,5))
sns.jointplot(x='shokuan_share',y='connection_share',data=df_merged)

# %%
sns.regplot(x='shokuan_share',y='connection_share',data=df_merged[df_merged.shokuan_share <= 1])

# %%
sns.jointplot(x='shokuan_share',y='total_graduates',data=df_merged)

# %%
sns.jointplot(x='shokuan_share',y='male_home_share',data=df_merged)

# %%
sns.regplot(x='shokuan_share',y='total_graduates',data=df_merged)

# %%
df = df_merged

# %%
import numpy as np

# %%
# Hypothesis: the first two digits in the school_id represents the city
school_group = [item[:-1] for item in df.school_id.unique().astype(str)]
school_group = np.unique(np.array(school_group).astype(int))

# Add school groups to the dataframe
for item in school_group:
    search = item.astype(str) + '[0-9]$'
    bool_match = df.school_id.astype(str).str.match(search)
    df.loc[bool_match, 'school_group'] = item

# %%
df
# Out:
#      school_id  male_graduates  male_high_school  male_part_time_high_school  \
# 0          101             172                43                          18
# 1          102             141                64                           6
# 2          103             300               218                           8
# 3          104             219               115                          18
# 4          105             220                67                          18
# ..         ...             ...               ...                         ...
# 181       1308              52                30                           3
# 182       1309              29                13                           4
# 183       1310              27                 6                           1
# 184       1311              32                 3                           0
# 185       1312              23                 8                           0
#
# ...

# %%
sns.catplot(x='school_group', y='shokuan_share' ,kind="boxen",data=df )

# %%
# Aggregate schools by groups
#df_school_grouped = df.iloc[:, 1:].groupby('school_group').sum()

# %%
#df_school_grouped

# %%
#df_merged = df_school_grouped

# %%
df_merged['total_employed']=df_merged['male_employed']+df_merged['female_employed']
df_merged['shokuan_share']=df_merged['school_and_shokuan']/df_merged['total_employed']
df_merged['connection_share']=df_merged['family_and_connection']/df_merged['total_employed']

# %%
df = df_merged

# %%
df
# Out:
#      school_id  male_graduates  male_high_school  male_part_time_high_school  \
# 0          101             172                43                          18
# 1          102             141                64                           6
# 2          103             300               218                           8
# 3          104             219               115                          18
# 4          105             220                67                          18
# ..         ...             ...               ...                         ...
# 181       1308              52                30                           3
# 182       1309              29                13                           4
# 183       1310              27                 6                           1
# 184       1311              32                 3                           0
# 185       1312              23                 8                           0
#
# ...

# %%
sns.distplot(df.shokuan_share)

# %%
df_merged
# Out:
#      school_id  male_graduates  male_high_school  male_part_time_high_school  \
# 0          101             172                43                          18
# 1          102             141                64                           6
# 2          103             300               218                           8
# 3          104             219               115                          18
# 4          105             220                67                          18
# ..         ...             ...               ...                         ...
# 181       1308              52                30                           3
# 182       1309              29                13                           4
# 183       1310              27                 6                           1
# 184       1311              32                 3                           0
# 185       1312              23                 8                           0
#
# ...

# %%
df_merged[df_merged.shokuan_share > 1]
# Out:
#      school_id  male_graduates  male_high_school  male_part_time_high_school  \
# 6          112             178                95                          35
# 8          114             188               120                          10
# 12         202              90                31                          11
# 30         244             268               194                          21
# 37         271             201                87                          23
# 46         305              79                37                           6
# 81         605             153                97                          17
# 130        917              90                31                          20
# 146       1019              32                17                           3
#
#      male_employed  male_home_and_high_school  male_home  male_others  \
# 6               24                          0         20            4
# ...

# %%
_df = df_merged[df_merged.shokuan_share < 1]
fig, ax = plt.subplots(figsize = (10,6))
ax = _df.shokuan_share.plot.hist(bins = 15, alpha = 0.6)
ax.set_xlabel('Percentage')
plt.title('Percentage of students who used the system to get a job')
plt.savefig('../../../../Graphs/Employed/SchShr.pdf')
plt.show()

# %%
import pandas as pd
df_school = pd.read_csv('../../../../Data/School/0001/school.csv')

# %%
df_school
# Out:
#      school_id  male_graduates  male_high_school  male_part_time_high_school  \
# 0          101             172                43                          18
# 1          102             141                64                           6
# 2          103             300               218                           8
# 3          104             219               115                          18
# 4          105             220                67                          18
# ..         ...             ...               ...                         ...
# 183       1308              52                30                           3
# 184       1309              29                13                           4
# 185       1310              27                 6                           1
# 186       1311              32                 3                           0
# 187       1312              23                 8                           0
#
# ...

# %%
df_school.male_graduates.sum()
# Out:
# 23027

# %%
df_school.female_graduates.sum()
# Out:
# 21302

# %%
df_school.male_home.sum()
# Out:
# 2944

# %%
df_school.female_home.sum()
# Out:
# 4861

# %%
df[df.gender == 1]
# Out:
#        school_id  gender  course_1 course_2 course_3 course_4 course_5  \
# 0            101       1         2
# 1            101       1         2
# 2            101       1         5
# 3            101       1         1
# 4            101       1         5
# ...          ...     ...       ...      ...      ...      ...      ...
# 13087       1312       1         5
# 13088       1312       1         5
# 13089       1312       1         5
# 13090       1312       1         5
# 13091       1312       1         5
#
#       course_6  heir  relation_to_the_guardian  ...  family_size  industry  \
# 0                  1                         3  ...           11        33
# 1                  1                         2  ...            4        36
# 2                  1                         1  ...            5        36
# 3                  2                         2  ...            5        36
# 4                  2                         3  ...            6        36
# ...

# %%
df[df.gender == 2]
# Out:
#        school_id  gender  course_1 course_2 course_3 course_4 course_5  \
# 109          101       2         1
# 110          101       2         5
# 111          101       2         4
# 112          101       2         4
# 113          101       2         1
# ...          ...     ...       ...      ...      ...      ...      ...
# 13098       1312       2         5        4
# 13099       1312       2         5        4
# 13100       1312       2         5        4
# 13101       1312       2         5        4
# 13102       1312       2         5        4
#
#       course_6  heir  relation_to_the_guardian  ...  family_size  industry  \
# 109                2                         2  ...            6        33
# 110                2                         2  ...            1         7
# 111                1                         2  ...            2        33
# 112                2                         1  ...            4        41
# ...

# %%
df_school
# Out:
#      school_id  male_graduates  male_high_school  male_part_time_high_school  \
# 0          101             172                43                          18
# 1          102             141                64                           6
# 2          103             300               218                           8
# 3          104             219               115                          18
# 4          105             220                67                          18
# ..         ...             ...               ...                         ...
# 183       1308              52                30                           3
# 184       1309              29                13                           4
# 185       1310              27                 6                           1
# 186       1311              32                 3                           0
# 187       1312              23                 8                           0
#
# ...

# %%
df_home = pd.read_csv('../../../../Data/School/0001/student_home.csv')

# %%
df_home[df_home.gender == 2]
# Out:
#       school_id  gender  course_1 course_2 course_3 course_4 course_5  \
# 17          101       2         4
# 18          101       2         4
# 19          101       2         4
# 20          101       2         4
# 21          101       2         4
# ...         ...     ...       ...      ...      ...      ...      ...
# 8050       1312       2         5        4
# 8051       1312       2         5        4
# 8052       1312       2         5        4
# 8053       1312       2         5        4
# 8054       1312       2         5        4
#
#      course_6  heir  relation_to_the_guardian  occupation_of_the_guardian  \
# 17                2                         1                           5
# 18                1                         1                           6
# 19                2                         3                          14
# 20                2                         3                           5
# ...

# %%
df_hs = pd.read_csv('../../../../Data/School/0001/student_high_school.csv')

# %%
df_hs[df_hs.gender == 1]
# Out:
#        school_id  gender  heir  relation_to_the_guardian  \
# 0            101       1     9                         1
# 1            101       1     9                         1
# 2            101       1     9                         4
# 3            101       1     9                         1
# 4            101       1     9                         2
# ...          ...     ...   ...                       ...
# 16553       1312       1     9                         4
# 16554       1312       1     9                         3
# 16555       1312       1     1                         2
# 16556       1312       1     9                         3
# 16557       1312       1     9                         4
#
#        occupation_of_the_guardian  academic_scores specialization  career_plan
# 0                              10                1                           2
# 1                              10                1                           1
# ...
