# %%
import pandas as pd
import os

directory = '../../Data/CareerHistory/0135'
file_name_label = '0135_honnin label.TXT'

file_label = os.path.join(directory, file_name_label)

# %%
file_name_data = '0135_honnin.csv'

file_data = os.path.join(directory, file_name_data)
df = pd.read_csv(file_data, sep = ',', error_bad_lines = False)

# %%
with open(file_label, 'r') as f:
    _x = f.read().splitlines()

# %%
def remove_empty_elements(x):
    x = [s for s in x if s]
    return x

# %%
x = remove_empty_elements(_x) # remove empty rows

# %%
def get_list_of_lists(x):
    # Return each row as a list
    list_of_lists = []
    for line in x:
        line = line.split(' ')
        line_0 = [line[0]]
        line_1 = remove_empty_elements(line[1:])
        list_of_lists.append(line_0 + line_1)
    return list_of_lists

# %%
list_of_lists = get_list_of_lists(x)

# %%
_list_of_vars = [item[0] for item in list_of_lists] # list of variables including empty rows

# %%
list_of_vars = remove_empty_elements(_list_of_vars)

# %%
def search_index(keyword, list_of_lists = list_of_lists):
    # Check if the keyword is in the list
    idx_list = []
    for idx, item in enumerate(list_of_lists):
        if keyword in item[1]:
            idx_list.append(idx)
    return idx_list

# %%
def search_keyword(keyword, list_of_lists = list_of_lists):
    variables = []
    for item in list_of_lists:
        if len(item) == 3:
            if keyword in item[1]:
                variables.append(item[0])
                
    # Remove empty elements
    variables = [item for item in variables if item]
    return variables

# %%
def return_next_var(var, list_of_vars = list_of_vars):
    # Use list of variables, taken from var_info, return the next variable
    current_idx = list_of_vars.index(var)
    next_var = list_of_vars[current_idx + 1]
    return next_var

# %%
def get_dict(var, 
             list_of_lists = list_of_lists,
             list_of_lists_1st_elem = _list_of_vars, 
             list_of_vars = list_of_vars):
    # Return dictionary for var
    
    dict = {}
    # Get the next variable using the list of variables in the values list
    next_var = return_next_var(var)
    
    # Get the index for the list of lists of values
    idx = list_of_lists_1st_elem.index(var)
    next_idx = list_of_lists_1st_elem.index(next_var)
    
    # Slice the list of lists
    sublist = list_of_lists[idx + 6 : next_idx]
    
    for item in sublist:
        new_dict = {item[1]:item[2]}
        dict.update(new_dict)
    return dict

# %%
def replace_val(keyword, df = df):
    variables = search_keyword(keyword)
    dictionary = get_dict(variables[0])
    for item in variables:
        df[item] = df[item].astype(str)
        df[item] = df[item].map(dictionary)

# %%
idxs = [_list_of_vars.index(item) for item in list_of_vars][2:]

# %%
# Can be used to replace column names
variables_dict = [{list_of_lists[idx][0]:list_of_lists[idx][1]} for idx in idxs]

# %%
variables_dict
# Out:
# [{'KEN': '居住地の県名'},
#  {'CITYSIZE': '住居地の地域特性'},
#  {'Q2': '婚姻上の地位'},
#  {'Q3': '同居家族数（実数）'},
#  {'Q4.1.1': '本人の性'},
#  {'Q4.1.2': '本人の年齢（実数）'},
#  {'Q4.2.1': '家族員の続き柄2'},
#  {'Q4.2.2': '家族員の性2'},
#  {'Q4.2.3': '家族員の年齢２(実数)'},
#  {'Q4.2.4': '家族員の職業２'},
#  {'Q4.3.1': '家族員の続き柄３'},
#  {'Q4.3.2': '家族員の性３'},
#  {'Q4.3.3': '家族員の年齢(実数)'},
#  {'Q4.3.4': '家族員の職業の有無３'},
#  {'Q4.4.1': '家族員の続き柄４'},
#  {'Q4.4.2': '家族員の性４'},
#  {'Q4.4.3': '家族員の年齢（実数）４'},
#  {'Q4.4.4': '家族員の職業の有無４'},
#  {'Q4.5.1': '家族員の続き柄５'},
#  {'Q4.5.2': '家族員の性５'},
#  {'Q4.5.3': '家族員の年齢（実数）５'},
#  {'Q4.5.4': '家族の職業の有無５'},
#  {'Q4.6.1': '家族員の続き柄６'},
#  {'Q4.6.2': '家族員の性６'},
#  {'Q4.6.3': '家族員の年齢（実数）６'},
#  {'Q4.6.4': '家族員の職業の有無'},
#  {'Q4.7.1': '家族員の続き柄７'},
#  {'Q4.7.2': '家族員の性７'},
#  {'Q4.7.3': '家族員の年齢（実数）７'},
#  {'Q4.7.4': '家族員の職業の有無７'},
#  {'Q4.8.1': '家族員の続き柄８'},
#  {'Q4.8.2': '家族員の性８'},
#  {'Q4.8.3': '家族員の年齢（実数）８'},
#  {'Q4.8.4': '家族員の職業の有無８'},
#  {'Q4.9.1': '家族員の続き柄９'},
#  {'Q4.9.2': '家族員の性９'},
#  {'Q4.9.3': '家族員の年齢（実数）９'},
#  {'Q4.9.4': '家族員の職業の有無９'},
#  {'Q4.10.1': '家族員の続き柄１０'},
#  {'Q4.10.2': '家族員の性１０'},
#  {'Q4.10.3': '家族員の年齢（実数）１０'},
#  {'Q4.10.4': '家族員の職業の有無'},
#  {'Q5': '就学による別居の子ども'},
#  {'Q6': '単身赴任の有無'},
#  {'Q6SQ': '単身赴任期間'},
#  {'Q7.1': '初婚年齢(実数)'},
#  {'Q7.2': '結婚年齢年齢(離・死別者)(実数)'},
#  {'Q7.3': '離別・死別の年齢(実数)'},
#  {'Q8.1': '出産児数(実数)'},
#  {'Q8.2': '第一子出産年齢(実数)'},
#  {'Q8.3': '末子出産年齢(実数)'},
#  {'Q8.4': '子との別居年齢(実数)'},
#  {'Q8.5': '子どもガ就職時の年齢'},
#  {'Q8.6': '子どもが結婚時の年齢(実数)'},
#  {'Q9': '職業の有無'},
#  {'Q9.1': '従業上の地位'},
#  {'Q9.1SQ1': '役職についた年齢（実数）'},
#  {'Q9.1SQ2': '管理職の経験'},
#  {'Q9.1SQ3A': '管理職就業開始年齢（実数）'},
#  {'Q9.1SQ3B': '管理職就業終了年齢'},
#  {'Q9.2': '職業小分類(仕事内容)'},
#  {'Q9.3': '産業中分類（事業内容）'},
#  {'Q9.4': '雇用者数'},
#  {'Q9.5.1': '就労時間数(実数)'},
#  {'Q9.5.2': '週労働日数'},
#  {'Q9.6': '通勤時間'},
#  {'Q10.1': '最初の従業上の地位'},
#  {'Q10.2': '従業上の地位開始年齢（実数）'},
#  {'Q10.2.1': '従業上の地位終了年齢（実数）'},
#  {'Q10.3': '職業小分類（仕事内容）'},
#  {'Q11.1': '就職以前の仕事の有無'},
#  {'Q11.2': '仕事経験の有無'},
#  {'Q13.1': '初職前の最終学歴'},
#  {'Q13.2': '卒業の有無'},
#  {'Q13.3.1': '通学開始（実数）'},
#  {'Q13.3.2': '通学終了(実数)'},
#  {'Q14': '初職後通学の有無'},
#  {'Q15.1': '最終学校卒業の有無'},
#  {'Q15.2': '最終学校卒業の有無'},
#  {'Q15.3.1': '最終学校通学開始（実数）'},
#  {'Q15.3.2': '最終学校通学終了（実数）'},
#  {'Q16': '就労希望の有無'},
#  {'Q16SQ1': '就職阻害理由'},
#  {'Q16SQ2': '働かない理由'},
#  {'Q17': '日常生活での相談相手（実数）'},
#  {'Q19.1': '相談相手（１人目）'},
#  {'Q19.2': '相談相手（2人目）'},
#  {'Q19.3': '相談相手（3人目）'},
#  {'Q19.4': '相談相手（4人目）'},
#  {'Q19.5': '相談相手（5人目）'},
#  {'Q20.1': '親族へ相談（一人目）'},
#  {'Q20.2': '親族へ相談（2人目）'},
#  {'Q20.3': '親族へ相談（3人）'},
#  {'Q20.4': '親族へ相談（4人目）'},
#  {'Q20.5': '親族へ相談（5人目）'},
#  {'Q20.1_1': '相談・職場や仕事関係'},
#  {'Q20.1_2': '相談・近所付きあいで'},
#  {'Q20.1_3': '相談・学校時代の先生'},
#  {'Q20.1_4': '相談・学校時代の友人'},
#  {'Q20.1_5': '相談・宗教活動関係'},
#  {'Q20.1_6': '相談・子どもの学校関係'},
#  {'Q20.1_7': '相談・サークル関係'},
#  {'Q20.1_8': '相談・その他自分の知人'},
#  {'Q20.1_9': '相談・配偶者の友人、知人'},
#  {'Q20.1_10': '相談・その他'},
#  {'Q20.1_N': 'Q20.1無回答欄'},
#  {'Q20.2_1': '相談・職場や仕事関係'},
#  {'Q20.2_2': '相談・近所付きあいで'},
#  {'Q20.2_3': '相談・学校時代の先生'},
#  {'Q20.2_4': '相談・学校時代の友人'},
#  {'Q20.2_5': '相談・宗教活動関係'},
#  {'Q20.2_6': '相談・子どもの学校関係'},
#  {'Q20.2_7': '相談・サークル関係'},
#  {'Q20.2_8': '相談・その他の自分の友人'},
#  {'Q20.2_9': '相談・配偶者の友人、知人'},
#  {'Q20.2_10': '相談・その他'},
#  {'Q20.2_N': 'Q20.2無回答欄'},
#  {'Q20.3_1': '相談・職場や仕事関係'},
#  {'Q20.3_2': '相談・近所づきあいで'},
#  {'Q20.3_3': '相談・学生時代の先生'},
#  {'Q20.3_4': '相談・学校時代の友人'},
#  {'Q20.3_5': '相談・宗教活動関係'},
#  {'Q20.3_6': '相談・子どもの学校関係'},
#  {'Q20.3_7': '相談・サークル関係'},
#  {'Q20.3.8': '相談・その他自分の知人'},
#  {'Q20.3_9': '相談・配偶者の友人、知人'},
#  {'Q20.3_10': '相談・その他'},
#  {'Q20.3_N': 'Q20.3無回答欄'},
#  {'Q20.4_1': '相談・職場や仕事関係'},
#  {'Q20.4_2': '相談・近所づきあいで'},
#  {'Q20.4.3': '相談・学校時代の先生'},
#  {'Q20.4_4': '相談・学校時代の友人'},
#  {'Q20.4_5': '相談・宗教活動関係'},
#  {'Q20.4_6': '相談・子どもの学校関係'},
#  {'Q20.4_7': '相談・サークル関係'},
#  {'Q20.4_8': '相談・その他自分の友人'},
#  {'Q20.4_9': '相談・配偶者の友人、知人'},
#  {'Q20.4_10': '相談・その他'},
#  {'Q20.4_N': 'Q20.4無回答欄'},
#  {'Q20.5_1': '相談・職場や仕事関係'},
#  {'Q20.5_2': '相談・近所づきあい'},
#  {'Q20.5_3': '相談・学校時代の先生'},
#  {'Q20.5_4': '相談・学校時代の友人'},
#  {'Q20.5_5': '相談・宗教活動関係'},
#  {'Q20.5_6': '相談・子どもの学校関係'},
#  {'Q20.5_7': '相談・サークル関係'},
#  {'Q20.5_8': '相談・その他自分の友人'},
#  {'Q20.5_9': '相談・配偶者の友人、知人'},
#  {'Q20.5_10': '相談・その他'},
#  {'Q20.5_N': 'Q20.5無回答欄'},
#  {'Q21.1': '相談相手の性別（1人目）'},
#  {'Q21.2': '相談相手の性別（2人目）'},
#  {'Q21.3': '相談相手の性別（3人目）'},
#  {'Q21.4': '相談相手の性別（4人目）'},
#  {'Q21.5': '相談相手の性別（5人目）'},
#  {'Q22.1': '相談者居住地（1人目）'},
#  {'Q22.2': '相談者居住地（2人目）'},
#  {'Q22.3': '相談者居住地（3人目）'},
#  {'Q22.4': '相談者居住地（4人目）'},
#  {'Q22.5': '相談者居住地（5人目）'},
#  {'Q23.1': '相談者への連絡（1人目）'},
#  {'Q23.2': '相談者への連絡（2人目）'},
#  {'Q23.3': '相談者への連絡（3人目）'},
#  {'Q23.4': '相談者への連絡（4人目）'},
#  {'Q23.5': '相談者への連絡（5人目）'},
#  {'Q24.1.1': '日常生活で頼る（1人目）'},
#  {'Q24.1.2': '仕事のサポートで頼る(1人目)'},
#  {'Q24.1.3': '暮らしの情報で頼る(1人目)'},
#  {'Q24.1.4': '仕事の情報で頼る（1人目）'},
#  {'Q24.1.5': '趣味やレジャーで頼る（1人目）'},
#  {'Q24.1.6': '資金援助で頼る（1人目）'},
#  {'Q24.2.1': '日常生活で頼る（2人目）'},
#  {'Q24.2.2': '仕事のサポートで頼る（2人目）'},
#  {'Q24.2.3': '暮らしの情報で頼る（2人目）'},
#  {'Q24.2.4': '仕事の情報で頼る（2人目）'},
#  {'Q24.2.5': '趣味やレジャーで頼る（2人目）'},
#  {'Q24.2_6': '資金援助で頼る（2人目）'},
#  {'Q24.3.1': '日常生活の上で頼る（3人目）'},
#  {'Q24.3.2': '仕事のサポートで頼る'},
#  {'Q24.3.3': '暮らしの情報で頼る（3人目）'},
#  {'Q24.3.4': '仕事の情報で頼る（3人目）'},
#  {'Q24.3.5': '趣味やレジャーで頼る（3人目）'},
#  {'Q24.3.6': '資金援助で頼る（3人目）'},
#  {'Q24.4.1': '日常生活上で頼る（4人目）'},
#  {'Q24.4.2': '仕事のサポートで頼る（4人目）'},
#  {'Q24.4.3': '暮らしの情報で頼る（4人目）'},
#  {'Q24.4.4': '仕事の情報で頼る（4人目）'},
#  {'Q24.4.5': '趣味やレジャーで頼る（4人目）'},
#  {'Q24.4.6': '資金援助で頼る（4人目）'},
#  {'Q24.5.1': '日常生活の上で頼る（5人目）'},
#  {'Q24.5.2': '仕事のサポートで頼る（5人目）'},
#  {'Q24.5.3': '暮らしの情報で頼る（5人目）'},
#  {'Q24.5.4': '仕事の情報で頼る（5人目）'},
#  {'Q24.5.5': '趣味やレジャーで頼る（5人目）'},
#  {'Q24.5.6': '資金援助で頼る（5人目）'},
#  {'Q25.1': '女性の望ましい人生'},
#  {'Q25.2': '配偶者の望ましい人生'},
#  {'Q26': '家事育児の分担'},
#  {'Q26S1': '専ら家事育児の担当'},
#  {'Q26S2': '主に家事育児の担当者'},
#  {'Q26S3': '家事育児のお手伝い'},
#  {'Q26S4.1': '主な家事担当者（1人目）'},
#  {'Q26S4.2': '家事育児のお手伝い（2人目）'},
#  {'Q27.1': '生活に活用：調理済み食品'},
#  {'Q27.2': '生活で活用：外食・出前'},
#  {'Q27.3': '生活で活用：全自動洗濯機'},
#  {'Q27.4': '生活で活用：クリーニング店'},
#  {'Q27.5': '生活で活用：まとめ買い'},
#  {'Q27.6': '生活で活用：留守番、子守り'},
#  {'Q27.7': '生活で活用：家政婦・家事代行'},
#  {'Q28': '住居形態'},
#  {'Q29': '本人収入'},
#  {'Q29A': '本人収入(実数)'},
#  {'Q30': '世帯収入'},
#  {'Q30A': '世帯収入（実数）'},
#  {'Q12': '職歴（実数）'},
#  {'Q12A1.1': '従事期間開始（実数）'},
#  {'Q12A1.2': '従事期間終了（実数）'},
#  {'Q12A2': '従業上の地位'},
#  {'Q12A3': '職業小分類（仕事内容）'},
#  {'Q12A4': '産業中分類（事業内容）'},
#  {'Q12A5': '雇用者数'},
#  {'Q12A6.1': '最初の従業上の地位'},
#  {'Q12A6.2': '年齢（実数）'},
#  {'Q12A7': '職業小分類（最初の仕事内容）'},
#  {'Q12B1.1': '従事期間開始（実数）'},
#  {'Q12B1.2': '従事期間終了（実数）'},
#  {'Q12B2': '従業上の地位'},
#  {'Q12B3': '職業小分類（主な仕事内容）'},
#  {'Q12B4': '産業中分類（事業の内容）'},
#  {'Q12B5': '雇用者数'},
#  {'Q12B6.1': '最初の従業上の地位'},
#  {'Q12B6.2': '年齢（実数）'},
#  {'Q12B7': '職業小分類（最初の仕事内容）'},
#  {'Q12C1.1': '従事期間開始（実数）'},
#  {'Q121C1.2': '従事期間終了(実数)'},
#  {'Q12C2': '従業上の地位'},
#  {'Q12C3': '職業小分類（主な仕事内容）'},
#  {'Q12C4': '産業中分類（主な仕事の内容）'},
#  {'Q12C5': '雇用者数'},
#  {'Q12C6.1': '最初の職業上の地位'},
#  {'Q12C6.2': '年齢（実数）'},
#  {'Q12C7': '職業小分類（最初の仕事内容）'},
#  {'Q12D1.1': '従事期間開始（実数）'},
#  {'Q12D1.2': '従事期間終了（実数）'},
#  {'Q12D2': '従業上の地位'},
#  {'Q12D3': '職業小分類（主な仕事の内容）'},
#  {'Q12D4': '産業中分類（事業の内容）'},
#  {'Q12D5': '雇用者数'},
#  {'Q12D6.1': '最初の従業上の地位'},
#  {'Q12D6.2': '年齢（実数）'},
#  {'Q12D7': '職業小分類（最初の仕事の内容）'},
#  {'Q12E1.1': '従事期間開始(実数)'},
#  {'Q12E1.2': '従事期間終了（実数）'},
#  {'Q12E2': '従業上の地位'},
#  {'Q12E3': '職業小分類（主な仕事内容）'},
#  {'Q12E4': '産業中分類（事業の内容）'},
#  {'Q12E5': '雇用者数'},
#  {'Q12E6.1': '最初の従業上の地位'},
#  {'Q12E6.2': '年齢（実数）'},
#  {'Q12E7': '職業小分類（最初の仕事内容）'},
#  {'Q12F1.1': '従事期間開始（実数）'},
#  {'Q12F1.2': '従事期間終了（実数）'},
#  {'Q12F2': '従業上の地位'},
#  {'Q12F3': '職業小分類（主な仕事内容）'},
#  {'Q12F4': '産業中分類（事業の内容）'},
#  {'Q12F5': '雇用者数'},
#  {'Q12F6.1': '最初の従業上の地位'},
#  {'Q12F6.2': '年齢（実数）'},
#  {'Q12F7': '職業小分類（最初の仕事内容）'},
#  {'Q12H1.1': '従業期間開始（実数）'},
#  {'Q12H1.2': '従業期間終了（実数）'},
#  {'Q12H2': '従業上の地位'},
#  {'Q12H3': '職業小分類（主な仕事内容）'},
#  {'Q12H4': '産業中分類（事業の内容）'},
#  {'Q12H5': '雇用者数'},
#  {'Q12H6.1': '最初の従業上の地位'},
#  {'Q12H6.2': '年齢（実数）'},
#  {'Q12H7': '職業小分類（最初の仕事内容）'},
#  {'Q12I1.1': '従事期間開始（実数）'},
#  {'Q12I1.2': '従事期間終了（実数）'},
#  {'Q12I2': '従業上の地位'},
#  {'Q12I3': '職業小分類（主な仕事内容）'},
#  {'Q12I4': '産業中分類(事業の内容)'},
#  {'Q12I5': '雇用者数'},
#  {'Q12I6.1': '最初の従業上の地位'},
#  {'Q12I6.2': '年齢（実数）'},
#  {'Q12I7': '職業小分類（最初の仕事内容）'},
#  {'Q12J1.1': '従事期間開始（実数）'},
#  {'Q12J1.2': '従事期間終了（実数）'},
#  {'Q12J2': '従業上の地位'},
#  {'Q12J3': '職業小分類（主な仕事内容）'},
#  {'Q12J4': '産業中分類（事業の内容）'},
#  {'Q12J5': '雇用者数'},
#  {'Q12J6.1': '最初の従業上の地位'},
#  {'Q12J6.2': '年齢（実数）'},
#  {'Q12J7': '職業小分類（最初の仕事内容）'},
#  {'Q12K1.1': '従事期間開始(実数)'},
#  {'Q12K1.2': '従事期間終了（実数）'},
#  {'Q12K2': '従業上の地位'},
#  {'Q12K3': '職業小分類（主な仕事内容）'},
#  {'Q12K4': '産業中分類（事業の内容）'},
#  {'Q12K5': '雇用者数'},
#  {'Q12K6.1': '最初の従業上の地位'},
#  {'Q12K6.2': '年齢（実数）'},
#  {'Q12K7': '職業小分類（最初の仕事内容）'},
#  {'Q12L1.1': '従事期間開始（実数）'},
#  {'Q12L1.2': '従事期間終了（実数）'},
#  {'Q12L2': '従業上の地位'},
#  {'Q12L3': '職業小分類(主な仕事内容)'},
#  {'Q12L4': '産業中分類（事業の内容）'},
#  {'Q12L5': '雇用者数'},
#  {'Q12L6.1': '最初の従業上の地位'},
#  {'Q12L6.2': '年齢（実数）'},
#  {'Q12L7': '職業小分類（最初の仕事内容）'},
#  {'Q12M1.1': '従事期間開始（実数）'},
#  {'Q12M1.2': '従事期間終了（実数）'},
#  {'Q12M2': '従業所の地位'},
#  {'Q12M3': '職業小分類（主な仕事内容）'},
#  {'Q12M4': '産業中分類（事業の内容）'},
#  {'Q12M5': '雇用者数'},
#  {'Q12M6.1': '最初の従業上の地位'},
#  {'Q12M6.2': '年齢(実数)'},
#  {'Q12M7': '職業小分類（最初の仕事内容）'},
#  {'Q12N1.1': '従事期間開始（実数）'},
#  {'Q12N1.2': '従事期間終了（実数）'},
#  {'Q12N2': '従業上の地位'},
#  {'Q12N3': '職業小分類（主な仕事内容）'},
#  {'Q12N4': '産業中分類（事業の内容）'},
#  {'Q12N5': '雇用者数'},
#  {'Q12N6.1': '最初の従業上の地位'},
#  {'Q12N6.2': '年齢（実数）'},
#  {'Q12N7': '職業小分類（最初の仕事内容）'},
#  {'Q12O1.1': '従事期間開始（実数）'},
#  {'Q12O1.2': '従事期間終了（実数）'},
#  {'Q12O2': '年齢（実数）'},
#  {'Q12O3': '職業小分類（主な仕事内容）'},
#  {'Q12O4': '産業中分類（事業の内容）'},
#  {'Q12O5': '雇用者数'},
#  {'Q12O6.1': '最初の従業上の地位'},
#  {'Q12O6.2': '年齢（実数）'},
#  {'Q12O7': '職業小分類（最初の仕事内容）'},
#  {'Q12P1.1': '従業期間開始（実数）'},
#  {'Q12P1.2': '従業期間終了（実数）'},
#  {'Q12P2': '従業上の地位'},
#  {'Q12P3': '職業小分類（主な仕事内容）'},
#  {'Q12P4': '産業中分類（事業内容）'},
#  {'Q12P5': '雇用者数'},
#  {'Q12P6.1': '最初の従業上の地位'},
#  {'Q12P6.2': '年齢（実数）'},
#  {'Q12P7': '職業小分類（最初の仕事内容）'}]

# %%
list_of_keywords = ['県', 
                    '地域特性',
                    'の性',
                    '職業の有無',
                    '産業中分類', 
                    '職業小分類',
                    '職業の有無',
#                    '従業上の地位',
                    '初職後通学の有無',
                    '初職前の最終学歴',    
                   ]

# %%
for keywords in list_of_keywords:
    replace_val(keywords)

# %%
for keyword in list_of_keywords:
    print(search_keyword(keyword))
# Out:
# ['KEN']
# ['CITYSIZE']
# ['Q4.1.1', 'Q4.2.2', 'Q4.3.2', 'Q4.4.2', 'Q4.5.2', 'Q4.6.2', 'Q4.7.2', 'Q4.8.2', 'Q4.9.2', 'Q4.10.2', 'Q21.1', 'Q21.2', 'Q21.3', 'Q21.4', 'Q21.5']
# ['Q4.3.4', 'Q4.4.4', 'Q4.5.4', 'Q4.6.4', 'Q4.7.4', 'Q4.8.4', 'Q4.9.4', 'Q4.10.4', 'Q9']
# ['Q9.3', 'Q12A4', 'Q12B4', 'Q12C4', 'Q12D4', 'Q12E4', 'Q12F4', 'Q12H4', 'Q12I4', 'Q12J4', 'Q12K4', 'Q12L4', 'Q12M4', 'Q12N4', 'Q12O4', 'Q12P4']
# ['Q9.2', 'Q10.3', 'Q12A3', 'Q12A7', 'Q12B3', 'Q12B7', 'Q12C3', 'Q12C7', 'Q12D3', 'Q12D7', 'Q12E3', 'Q12E7', 'Q12F3', 'Q12F7', 'Q12H3', 'Q12H7', 'Q12I3', 'Q12I7', 'Q12J3', 'Q12J7', 'Q12K3', 'Q12K7', 'Q12L3', 'Q12L7', 'Q12M3', 'Q12M7', 'Q12N3', 'Q12N7', 'Q12O3', 'Q12O7', 'Q12P3', 'Q12P7']
# ['Q4.3.4', 'Q4.4.4', 'Q4.5.4', 'Q4.6.4', 'Q4.7.4', 'Q4.8.4', 'Q4.9.4', 'Q4.10.4', 'Q9']
# ['Q14']
# ['Q13.1']

# %%
df
# Out:
#           ID KEN     CITYSIZE  Q2  Q3 Q4.1.1  Q4.1.2 Q4.2.1 Q4.2.2 Q4.2.3  \
# 0          0  岩手  人口10万人未満の都市   2   6      男      44      1      女     42
# 1          1  岩手  人口10万人未満の都市   2   4      男      53      1      女     44
# 2          2  岩手  人口10万人未満の都市   2   5      男      63      1      女     59
# 3          3  岩手  人口10万人未満の都市   2   4      男      54      1      女     54
# 4          5  岩手  人口10万人未満の都市   1   3      男      40      8      男     65
# ...      ...  ..          ...  ..  ..    ...     ...    ...    ...    ...
# 4874  990115  埼玉       郡部（町村）   2   5      女      47      1      男     50
# 4875  990116  埼玉       郡部（町村）   2   7      女      38      1      男     40
# 4876  990117  埼玉       郡部（町村）   2   2      女      63      1      男     68
# 4877  990118  埼玉       郡部（町村）   2   2      女      49      1      男     51
# 4878  990119  埼玉       郡部（町村）   2   5      女      40      1      男     43
#
#       ... Q12O7 Q12P1.1 Q12P1.2 Q12P2 Q12P3 Q12P4 Q12P5 Q12P6.1 Q12P6.2 Q12P7
# 0     ...   NaN                         NaN   NaN                         NaN
# 1     ...   NaN                         NaN   NaN                         NaN
# 2     ...   NaN                         NaN   NaN                         NaN
# 3     ...   NaN                         NaN   NaN                         NaN
# 4     ...   NaN                         NaN   NaN                         NaN
# ...   ...   ...     ...     ...   ...   ...   ...   ...     ...     ...   ...
# 4874  ...   NaN                         NaN   NaN                         NaN
# 4875  ...   NaN                         NaN   NaN                         NaN
# 4876  ...   NaN                         NaN   NaN                         NaN
# 4877  ...   NaN                         NaN   NaN                         NaN
# 4878  ...   NaN                         NaN   NaN                         NaN
#
# [4879 rows x 352 columns]

# %%
df.to_csv('0135honnin.csv')
