# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('../ReplaceVal/0133.csv', index_col = 0)

# %%
df.chrt.unique()
# Out:
# array([1928, 1920, 1932, 1912, 1936, 1914, 1927, 1926, 1925, 1916, 1933,
#        1942, 1944, 1939, 1937, 1935, 1941, 1938, 1953, 1915, 1945, 1948,
#        1917, 1919, 1955, 1950, 1931, 1934, 1929, 1921, 1943, 1956, 1913,
#        1949, 1946, 1952, 1940, 1923, 1954, 1924, 1951, 1947, 1922, 1930,
#        1918])

# %%
# Prepare cohort size to plot shares

# %%
chrt_sz_dict = df.chrt.value_counts().to_dict()

# %%
df['chrt_sz'] = df.chrt.map(chrt_sz_dict)

# %%
fig, ax = plt.subplots()
ax = df.chrt.value_counts().sort_index().plot(kind = 'bar')
plt.title('Birth cohort')
ax.set_xlabel('Birth year')
ax.set_ylabel('Counts')
plt.show()

# %%
fig, ax = plt.subplots()
ax = df.curr_liv_pref.value_counts().sort_index().plot(kind = 'bar')
plt.title('Currently living prefecture')
ax.set_xlabel('Currently living prefecture')
ax.set_ylabel('Counts')
plt.show()

# %%
fig, ax = plt.subplots()
ax = df.compul_edu_pref.value_counts().sort_index().plot(kind = 'bar')
plt.title('Prefecture Compulsory Education')
ax.set_xlabel('Prefecture')
ax.set_ylabel('Counts')
plt.show()

# %%
_df = df[['mv', 'chrt']]
_df_1 = _df[_df.mv == 1]
_df_2 = _df[_df.mv == 2]

fig, ax = plt.subplots()
ax = _df_1.chrt.value_counts().sort_index().plot(kind = 'bar', color = 'r', label = 'not moved')
ax = _df_2.chrt.value_counts().sort_index().plot(kind = 'bar', bottom = _df_1.chrt.value_counts().sort_index(), 
                                                    color = 'b', label ='moved')
plt.title('Birth cohort')
ax.set_xlabel('Birth year')
ax.set_ylabel('Counts')
plt.legend()
plt.show()

# %%
_df = df.copy()
_df_mv_dmmy = pd.get_dummies(_df, columns = ['mv'])

# %%
_df_mv_dmmy['chrt']
# Out:
# 0       1928
# 1       1920
# 2       1932
# 3       1912
# 4       1936
#         ...
# 4250    1939
# 4251    1930
# 4252    1929
# 4253    1934
# 4254    1948
# Name: chrt, Length: 4255, dtype: int64

# %%
_df_mv_dmmy = _df_mv_dmmy[['mv_1', 'mv_2', 'chrt']]

# %%
_df_gb_chrt_mv = _df_mv_dmmy.groupby('chrt').sum().reset_index()

# %%
_df_gb_chrt_mv['mv_tot'] = _df_gb_chrt_mv['mv_1'] + _df_gb_chrt_mv['mv_2']

# %%
_df_gb_chrt_mv['mv_1'] = _df_gb_chrt_mv['mv_1']/_df_gb_chrt_mv['mv_tot']

# %%
_df_gb_chrt_mv['mv_2'] = _df_gb_chrt_mv['mv_2']/_df_gb_chrt_mv['mv_tot']

# %%
_df_1 = _df_gb_chrt_mv[['mv_1', 'chrt']].set_index('chrt')
_df_2 = _df_gb_chrt_mv[['mv_2', 'chrt']].set_index('chrt')

# %%
fig, ax = plt.subplots()
ax = _df_1.mv_1.plot(kind = 'bar', width = 1, color = 'r', label = 'not moved')
ax = _df_2.mv_2.plot(kind = 'bar', width = 1, bottom = _df_1.mv_1, label = 'moved')
plt.legend()

# %% [markdown]
# I don't see any patterns may need to subsample

# %%
df
# Out:
#         id  curr_liv_pref  age  mv  compul_edu_pref  compul_edu_ctype  \
# 0        1             10   53   1               10                 4
# 1        2             10   61   1               10                 4
# 2        3             10   49   1               10                 4
# 3        4             10   69   1               10                 4
# 4        5             10   45   1               10                 4
# ...    ...            ...  ...  ..              ...               ...
# 4250  4251             47   42   1               47                 4
# 4251  4252             47   51   1               47                 4
# 4252  4253             47   52   1               47                 4
# 4253  4254             47   47   1               47                 4
# 4254  4255             47   33   1               47                 4
#
#       num_sib  b_ord  num_sib_male  b_ord_male  ...  wife_ind_min  wife_pos  \
# 0           4      3             3           3  ...            66         8
# 1           4      3             3           3  ...           997         8
# 2           6      3             1           1  ...           997         8
# 3           9      6             6           6  ...           997         8
# 4           4      1             3           1  ...            66         8
# ...       ...    ...           ...         ...  ...           ...       ...
# 4250        4      4             2           2  ...           997         8
# 4251        5      4             1           1  ...           997         8
# 4252        1      1             1           1  ...           997         8
# 4253        7      4             6           3  ...           251         1
# 4254        6      5             3           2  ...           997         8
#
#       wife_f_sz  wife_fin_edu  inc_hh  q32_1  inc_ind  q33_1  chrt  chrt_sz
# 0             1             2      99    998       99    998  1928       92
# 1            98             2      99    998       99    998  1920       61
# 2            98             7      99    998       99    998  1932      110
# 3            98             1      99    998       99    998  1912       52
# 4             2             6      99    998       99    998  1936      122
# ...         ...           ...     ...    ...      ...    ...   ...      ...
# 4250         98             8       5    998        5    998  1939      105
# 4251         98             1       8    998        5    998  1930      113
# 4252         98             2       4    998        4    998  1929       82
# 4253         99             6       4    998        4    998  1934      115
# 4254         98             7       8    998        8    998  1948      131
#
# [4255 rows x 408 columns]

# %%
fig, ax = plt.subplots()
ax = df.curr_liv_pref.value_counts().sort_index().plot(kind = 'bar')
plt.title('Currently living prefecture')
ax.set_xlabel('Currently living prefecture')
ax.set_ylabel('Counts')
plt.show()

# %%
fig, ax = plt.subplots()
ax = df.compul_edu_pref.value_counts().sort_index().plot(kind = 'bar')
plt.title('Prefecture Compulsory Education')
ax.set_xlabel('Prefecture')
ax.set_ylabel('Counts')
plt.show()

# %%
fig, ax = plt.subplots()
ax = _df_1.mv_1.plot(kind = 'bar', width = 1, color = 'r', label = 'not moved')
ax = _df_2.mv_2.plot(kind = 'bar', width = 1, bottom = _df_1.mv_1, label = 'moved')
plt.legend()

# %%
_df  = df[df.curr_liv_pref == 1]
_df
# Out:
#         id  curr_liv_pref  age  mv  compul_edu_pref  compul_edu_ctype  \
# 1467  1468              1   37   2                1                 3
# 1468  1469              1   29   2                1                 3
# 1469  1470              1   48   2                1                 3
# 1470  1471              1   41   1                1                 1
# 1471  1472              1   38   2                4                 3
# ...    ...            ...  ...  ..              ...               ...
# 4155  4156              1   35   1                1                 3
# 4156  4157              1   60   2                5                 4
# 4157  4158              1   64   2                2                 3
# 4158  4159              1   45   2               43                 2
# 4159  4160              1   65   2               12                 1
#
#       num_sib  b_ord  num_sib_male  b_ord_male  ...  wife_ind_min  wife_pos  \
# 1467        3      3             3           3  ...            66         1
# 1468        2      1             1           1  ...           997         8
# 1469        7      3             5           3  ...           258         1
# 1470        7      6             5           5  ...           260         8
# 1471        5      3             1           1  ...           260         1
# ...       ...    ...           ...         ...  ...           ...       ...
# 4155        8      5             5           5  ...           998         8
# 4156        8      4             5           3  ...           997         8
# 4157        5      5             2           2  ...           997         8
# 4158        2      2             2           2  ...           997         8
# 4159        4      1             2           1  ...           997         8
#
#       wife_f_sz  wife_fin_edu  inc_hh  q32_1  inc_ind  q33_1  chrt  chrt_sz
# 1467         99             7       9    998        8    998  1944      115
# 1468         98             7       5    998        5    998  1952       98
# 1469          4             7      14    998       13    998  1933      117
# 1470          1             6      99    998       99    998  1940      127
# 1471          4             6       5    998        4    998  1943      118
# ...         ...           ...     ...    ...      ...    ...   ...      ...
# 4155         98            98      99    998       99    998  1946      104
# 4156         98             1       5    998        5    998  1921       63
# 4157         98             2       7    998        4    998  1917       57
# 4158         98             7      11    998       11    998  1936      122
# 4159         98             2       4    998        4    998  1916       56
#
# [212 rows x 408 columns]

# %%
_df = df[df.compul_edu_pref == 4]
                                    
_df_1 = _df[_df.mv == 1]
_df_2 = _df[_df.mv == 2]

fig, axs = plt.subplots(1,2)
_df_1.chrt.value_counts().sort_index().plot(kind = 'bar', color = 'r', label = 'not moved', ax = axs[0])
_df_2.chrt.value_counts().sort_index().plot(kind = 'bar', color = 'b', label ='moved', ax = axs[1])
axs[0].title.set_text('Not moved')
axs[1].title.set_text('Moved')
fig.suptitle('Prefecture 4')
plt.legend()
plt.show()

# %%
_df = df[df['init_j_edu_deg'] == 7] # Select Mid School Graduates after WW2
_df = _df[['init_chnl', 'chrt']]

# %%
# Aggregate employment chanel
chnl_agg = {
    1: 'CONN',
    2: 'CONN',
    3: 'SCH',
    4: 'PES',
    5: 'AD',
    6: 'ORS',
    7: 'SE',
    8: 'TW',
    98: 'ORS',
    99: 'UNK'
}

# %%
_df['chnl_agg'] = _df['init_chnl'].map(chnl_agg)

# %%
fig, ax = plt.subplots()
ax = _df.chrt.value_counts().sort_index().plot(kind = 'bar', color = 'b', label = 'School')

plt.title('Cohort Size')
ax.set_xlabel('Birth year')
ax.set_ylabel('Counts')
plt.legend()
plt.show()

# %%
_df_1 = _df[_df.chnl_agg == 'CONN']
fig, ax = plt.subplots()
ax = _df_1.chrt.value_counts().sort_index().plot(kind = 'bar', color = 'r', label = 'Connection')

plt.title('Employment channel for the first job')
ax.set_xlabel('Birth year')
ax.set_ylabel('Counts')
plt.legend()
plt.show()

# %%
_df_1 = _df[_df.chnl_agg == 'SCH']
fig, ax = plt.subplots()
ax = _df_1.chrt.value_counts().sort_index().plot(kind = 'bar', color = 'b', label = 'School')

plt.title('Employment channel for the first job')
ax.set_xlabel('Birth year')
ax.set_ylabel('Counts')
plt.legend()
plt.show()

# %%
_df_1 = _df[_df.chnl_agg == 'SE']
fig, ax = plt.subplots()
ax = _df_1.chrt.value_counts().sort_index().plot(kind = 'bar', color = 'b', label = 'Self Employed')

plt.title('Employment channel for the first job')
ax.set_xlabel('Birth year')
ax.set_ylabel('Counts')
plt.legend()
plt.show()

# %%
_df_1 = _df[_df.chnl_agg == 'AD']
fig, ax = plt.subplots()
ax = _df_1.chrt.value_counts().sort_index().plot(kind = 'bar', color = 'b', label = 'Advertisement')

plt.title('Employment channel for the first job')
ax.set_xlabel('Birth year')
ax.set_ylabel('Counts')
plt.legend()
plt.show()

# %%
_df_1 = _df[_df.chnl_agg == 'SCH']
_df_2 = _df[_df.chnl_agg == 'CONN']
fig, ax = plt.subplots()
ax = _df.chrt.value_counts().sort_index().plot(kind = 'bar', color = 'b', label = 'Total')
ax = _df_1.chrt.value_counts().sort_index().plot(kind = 'bar', color = 'r', label = 'School')
#ax = _df_2.chrt.value_counts().sort_index().plot(kind = 'bar', bottom = _df_1.chrt.value_counts().sort_index(), 
#                                                    color = 'g', label ='Connection')

plt.title('Employment channel for the first job')
ax.set_xlabel('Birth year')
ax.set_ylabel('Counts')
plt.legend()
plt.show()

# %%
_df_1 = _df[_df.chnl_agg == 'SCH']
_df_2 = _df[_df.chnl_agg == 'CONN']
fig, ax = plt.subplots()
ax = _df.chrt.value_counts().sort_index().plot(kind = 'bar', color = 'b', label = 'Total')
ax = _df_1.chrt.value_counts().sort_index().plot(kind = 'bar', color = 'r', label = 'School')
ax = _df_2.chrt.value_counts().sort_index().plot(kind = 'bar', bottom = _df_1.chrt.value_counts().sort_index(), 
                                                    color = 'g', label ='Connection')

plt.title('Employment channel for the first job')
ax.set_xlabel('Birth year')
ax.set_ylabel('Counts')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-337-d19e993df9f9> in <module>
#       5 ax = _df_1.chrt.value_counts().sort_index().plot(kind = 'bar', color = 'r', label = 'School')
#       6 ax = _df_2.chrt.value_counts().sort_index().plot(kind = 'bar', bottom = _df_1.chrt.value_counts().sort_index(),
# ----> 7                                                     color = 'g', label ='Connection')
#       8
#       9 plt.title('Employment channel for the first job')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     261         self._compute_plot_data()
#     262         self._setup_subplots()
# --> 263         self._make_plot()
#     264         self._add_table()
#     265         self._make_legend()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in _make_plot(self)
#    1403                     label=label,
#    1404                     log=self.log,
# -> 1405                     **kwds,
#    1406                 )
#    1407             self._add_legend_handle(rect, label, index=i)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in _plot(cls, ax, x, y, w, start, log, **kwds)
#    1328     @classmethod
#    1329     def _plot(cls, ax, x, y, w, start=0, log=False, **kwds):
# -> 1330         return ax.bar(x, y, w, bottom=start, log=log, **kwds)
#    1331
#    1332     @property
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2372         x, height, width, y, linewidth = np.broadcast_arrays(
#    2373             # Make args iterable too.
# -> 2374             np.atleast_1d(x), height, width, y, linewidth)
#    2375
#    2376         # Now that units have been converted, set the tick locations.
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/stride_tricks.py in broadcast_arrays(*args, **kwargs)
#     262     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     263
# --> 264     shape = _broadcast_shape(*args)
#     265
#     266     if all(array.shape == shape for array in args):
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/stride_tricks.py in _broadcast_shape(*args)
#     189     # use the old-iterator because np.nditer does not handle size 0 arrays
#     190     # consistently
# --> 191     b = np.broadcast(*args[:32])
#     192     # unfortunately, it cannot handle 32 or more arguments directly
#     193     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %%
_df_1 = _df[_df.chnl_agg == 'CONN']
fig, ax = plt.subplots()
ax = _df.chrt.value_counts().sort_index().plot(kind = 'bar', color = 'b', label = 'Total')
ax = _df_1.chrt.value_counts().sort_index().plot(kind = 'bar', color = 'r', label = 'Connection')
#ax = _df_2.chrt.value_counts().sort_index().plot(kind = 'bar', bottom = _df_1.chrt.value_counts().sort_index(), 
#                                                    color = 'b', label ='School')

plt.title('Employment channel for the first job')
ax.set_xlabel('Birth year')
ax.set_ylabel('Counts')
plt.legend()
plt.show()

# %%
_df = df[df['init_j_edu_deg'] == 7] # Select Mid School Graduates after WW2
_df = _df[['init_chnl', 'chrt']]

# %%
# Aggregate employment chanel
chnl_agg = {
    1: 'CONN',
    2: 'CONN',
    3: 'SCH',
    4: 'SCH',
    5: 'AD',
    6: 'ORS',
    7: 'SE',
    8: 'WF',
    98: 'ORS',
    99: 'UNK'
}

# %%
_df['chnl_agg'] = _df['init_chnl'].map(chnl_agg)

# %%
_df = _df[['chrt', 'chnl_agg']]

# %%
_df['total'] = 1 # use ones to create total

# %%
_df_ch_dmmy = pd.get_dummies(_df, columns = ['chnl_agg'])

# %%
_df_ch_dmmy.columns
# Out:
# Index(['chrt', 'total', 'chnl_agg_AD', 'chnl_agg_CONN', 'chnl_agg_ORS',
#        'chnl_agg_SCH', 'chnl_agg_SE', 'chnl_agg_UNK'],
#       dtype='object')

# %%
_df_gb_chrt_ch = _df_ch_dmmy.groupby('chrt').sum().reset_index()

# %%
_df_gb_chrt_ch['class'] = _df_gb_chrt_ch['chrt'] + 15

# %%
_df_gb_chrt_ch.set_index('class')
# Out:
#        chrt  total  chnl_agg_AD  chnl_agg_CONN  chnl_agg_ORS  chnl_agg_SCH  \
# class
# 1942   1927      1            0              0             0             1
# 1943   1928      1            0              1             0             0
# 1945   1930      3            0              0             0             1
# 1946   1931      2            1              0             0             0
# 1947   1932     15            1              6             0             4
# 1948   1933     34            2             11             0             1
# 1949   1934     44            0             21             1             5
# 1950   1935     49            1             19             2             4
# 1951   1936     52            4             21             1            10
# 1952   1937     49            2             20             0             8
# 1953   1938     39            1             25             0             2
# 1954   1939     34            2             21             0             3
# 1955   1940     44            1             20             1            11
# 1956   1941     54            2             23             2            12
# 1957   1942     40            1             22             0            10
# 1958   1943     32            1             12             0            13
# 1959   1944     31            1             15             0            10
# 1960   1945     29            3             11             1             9
# 1961   1946     24            0              9             1            10
# 1962   1947     22            2              7             0            11
# 1963   1948     32            1             15             0            11
# 1964   1949     27            0              5             1            19
# 1965   1950     23            0              8             1             9
# 1966   1951     17            1              5             0             9
# 1967   1952     22            0             10             0            10
# 1968   1953     10            0              5             1             2
# 1969   1954     11            0              5             1             3
# 1970   1955      6            0              1             0             5
# 1971   1956      8            0              4             0             2
#
#        chnl_agg_SE  chnl_agg_UNK
# class
# 1942             0             0
# 1943             0             0
# 1945             2             0
# 1946             1             0
# 1947             4             0
# 1948            17             3
# 1949            16             1
# 1950            21             2
# 1951            16             0
# 1952            16             3
# 1953            10             1
# 1954             7             1
# 1955            11             0
# 1956            13             2
# 1957             7             0
# 1958             6             0
# 1959             5             0
# 1960             4             1
# 1961             3             1
# 1962             1             1
# 1963             4             1
# 1964             0             2
# 1965             5             0
# 1966             2             0
# 1967             2             0
# 1968             2             0
# 1969             2             0
# 1970             0             0
# 1971             1             1

# %%
_df_gb_chrt_ch.to_csv('male.csv')

# %%
_df = _df_gb_chrt_ch.set_index('class')
fig, ax = plt.subplots()
ax = _df.total.plot(kind = 'bar', color = 'b', label = 'Total')
ax = _df.chnl_agg_SCH.plot(kind = 'bar', color = 'r', label = 'School')
ax = _df.chnl_agg_CONN.plot(kind = 'bar', bottom = _df.chnl_agg_SCH, 
                                                   color = 'g', label ='Connection')

plt.title('Employment channel for the first job')
ax.set_xlabel('Class')
ax.set_ylabel('Counts')
plt.legend()
plt.show()

# %%
import seaborn as sns
sns.set()

# %%
_df_gb_chrt_mv['mv_tot'] = _df_gb_chrt_mv['mv_1'] + _df_gb_chrt_mv['mv_2']

# %%
_df_gb_chrt_mv['mv_1'] = _df_gb_chrt_mv['mv_1']/_df_gb_chrt_mv['mv_tot']

# %%
_df_gb_chrt_mv['mv_2'] = _df_gb_chrt_mv['mv_2']/_df_gb_chrt_mv['mv_tot']

# %%
_df_1 = _df_gb_chrt_mv[['mv_1', 'chrt']].set_index('chrt')
_df_2 = _df_gb_chrt_mv[['mv_2', 'chrt']].set_index('chrt')

# %%
fig, ax = plt.subplots()
ax = _df_1.mv_1.plot(kind = 'bar', width = 1, color = 'r', label = 'not moved')
ax = _df_2.mv_2.plot(kind = 'bar', width = 1, bottom = _df_1.mv_1, label = 'moved')
plt.legend()
